# %% [markdown]
# # Bookworm
#
#
# ## Overview
#
# In this project, you will build a simple question-answering agent that is able to learn from any text data you provide, and answer queries posed in natural language. You will use IBM Watson's cloud-based services to process the input text data and find relevant responses.
#
# ## Learning Objectives
#
# By completing this project, you will learn how to:
#
# - Create a cloud-based NLP service instance and configure it.
# - Ingest a set of text documents using the service and analyze the results.
# - Accept questions in natural language and parse them.
# - Find relevant answers from the preprocessed text data.
#
# ## Getting Started
#
# In order to use Watson's cloud-based services, you first need to create an account on the [IBM Bluemix platform](https://console.ng.bluemix.net/).
#
# <div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/watson-logo.png" alt="IBM Watson logo" width="200" />
#     </div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/bluemix-logo.png" alt="IBM Bluemix logo" width="400" />
#     </div>
# </div>
#
# Then, for each service you want to use, you have to create an instance of that service. You can continue with the tasks below, and create a service instance when indicated.

# %% [markdown]
# ## 1. Create and configure Discovery service
#
# Create an instance of the **Discovery** service. You will use this to process a set of text documents, and _discover_ relevant facts and relationships.
#
# - Go to the [IBM Bluemix Catalog](https://console.ng.bluemix.net/catalog/?taxonomyNavigation=services&category=watson).
# - Select the service you want, **Discovery**, under the **Watson** category.
# - Enter a Service Name for that instance, e.g. **Disco1** and a Credential Name, e.g. **Disco1-Creds** (these are just for you to be able to refer to later, they do not affect the functioning of the service).
# - You should be able to see your newly-created service in your [Services Dashboard](https://console.ng.bluemix.net/dashboard/services).
# - Open the service instance, click on the **Service credentials** tab, and then **View credentials** under Actions. This is where you will find the username and password to use when connecting to the service.
#
# <img src="images/discovery-creds.png" alt="Discovery Service - Credentials tab" width="800" />
#
# Save the credentials for the discovery service in a JSON file in the current directory named `service-credentials.json` with the following format:
#
# ```json
# {
#     "discovery": {
#         "username": "<your Discovery username here>",
#         "password": "<your Discovery password here>"
#     },
#     "conversation": {
#         "username": "",
#         "password": ""
#     }
# }
#
# ```
#
# You will be filling out the Conversation service credentials later, when you create an instance for it. Note that you should keep these credentials secret. Please do not turn them in with your submission!
#
# ### Connect to the service instance
#
# Let's connect to the service instance you just created using IBM Watson's [Python SDK](https://github.com/watson-developer-cloud/python-sdk). You will first need to install the SDK:
# ```bash
# pip install watson-developer-cloud
# ```
#
# Now execute each code cell below using **`Shift+Enter`**, and complete any steps indicated by a **`TODO`** comment. For more information on the Discovery service, please read the [Documentation](https://www.ibm.com/watson/developercloud/doc/discovery/index.html) and look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python) as needed.

# %%
# Usual Python imports
import sys
import os
import glob
import json

# BeautifulSoup, for parsing HTML
from bs4 import BeautifulSoup

# Matplotlib, for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Watson Python SDK
import watson_developer_cloud

# Utility functions
import helper

# %%
# Connect to the Discovery service instance
# TODO: Ensure that your username and password from the Service Credentials tab are in service-credentials.json
# Note that these credentials are different from your IBM Bluemix login, and are specific to the service instance
discovery_creds = helper.fetch_credentials('discovery')
discovery = watson_developer_cloud.DiscoveryV1(
    version='2016-11-07',
    username=discovery_creds['username'],
    password=discovery_creds['password'])

# %% [markdown]
# ### Create an environment
#
# The Discovery service organizes everything needed for a particular application in an _environment_. Let's create one called "Bookworm" for this project.
#
# > _**Note**: It is okay to run this block multiple times - it will not create duplicate environments with the same name._

# %%
# Prepare an environment to work in
env, env_id = helper.fetch_object(
    discovery, "environment", "Bookworm",
    create=True, create_args=dict(
        description="A space to read and understand stories",  # feel free to edit
        size=0  # use 0 for free plan (see API reference for more on sizing)
    ))
print(json.dumps(env, indent=2))
# Out:
# Found environment: Bookworm (9ac37d11-b26b-43c7-91bb-664719e979f4)
# {
#   "status": "active",
#   "read_only": false,
#   "updated": "2017-07-01T13:05:43.124Z",
#   "environment_id": "9ac37d11-b26b-43c7-91bb-664719e979f4",
#   "name": "Bookworm",
#   "created": "2017-07-01T13:05:43.124Z",
#   "index_capacity": {
#     "disk_usage": {
#       "total": "4 GB",
#       "percent_used": 0.0,
#       "used": "0 KB",
#       "used_bytes": 0,
#       "total_bytes": 4294967296
#     },
#     "memory_usage": {
#       "total": "1007.38 MB",
#       "percent_used": 12.28,
#       "used": "123.72 MB",
#       "used_bytes": 129727128,
#       "total_bytes": 1056309248
#     }
#   },
#   "size": 0,
#   "description": "A space to read and understand stories"
# }

# %% [markdown]
# ### Verify configuration options
#
# A _configuration_ defines what natural language processing routines are applied to any documents that are submitted to the service. Each environment gets a default configuration when it is created.
#
# You can fetch the default configuration and view the different options using the following piece of code.

# %%
# View default configuration
cfg_id = discovery.get_default_configuration_id(environment_id=env_id)
cfg = discovery.get_configuration(environment_id=env_id, configuration_id=cfg_id)
print(json.dumps(cfg, indent=2))
# Out:
# {
#   "conversions": {
#     "json_normalizations": [],
#     "pdf": {
#       "heading": {
#         "fonts": [
#           {
#             "min_size": 24,
#             "max_size": 80,
#             "level": 1
#           },
#           {
#             "min_size": 18,
#             "italic": false,
#             "bold": false,
#             "max_size": 24,
#             "level": 2
#           },
#           {
#             "min_size": 18,
#             "bold": true,
#             "max_size": 24,
#             "level": 2
#           },
#           {
#             "min_size": 13,
#             "italic": false,
#             "bold": false,
#             "max_size": 18,
#             "level": 3
#           },
#           {
#             "min_size": 13,
#             "bold": true,
#             "max_size": 18,
#             "level": 3
#           },
#           {
#             "min_size": 11,
#             "italic": false,
#             "bold": false,
#             "max_size": 13,
#             "level": 4
#           }
#         ]
#       }
#     },
#     "html": {
#       "keep_content": {
#         "xpaths": []
#       },
#       "exclude_tag_attributes": [
#         "EVENT_ACTIONS"
#       ],
#       "exclude_tags_keep_content": [
#         "font",
#         "em",
#         "span"
#       ],
#       "exclude_tags_completely": [
#         "script",
#         "sup"
#       ],
#       "exclude_content": {
#         "xpaths": []
#       }
#     },
#     "word": {
#       "heading": {
#         "styles": [
#           {
#             "names": [
#               "pullout heading",
#               "pulloutheading",
#               "header"
#             ],
#             "level": 1
#           },
#           {
#             "names": [
#               "subtitle"
#             ],
#             "level": 2
#           }
#         ],
#         "fonts": [
#           {
#             "min_size": 24,
#             "bold": false,
#             "italic": false,
#             "level": 1
#           },
#           {
#             "min_size": 18,
#             "italic": false,
#             "bold": true,
#             "max_size": 23,
#             "level": 2
#           },
#           {
#             "min_size": 14,
#             "italic": false,
#             "bold": false,
#             "max_size": 17,
#             "level": 3
#           },
#           {
#             "min_size": 13,
#             "italic": false,
#             "bold": true,
#             "max_size": 13,
#             "level": 4
#           }
#         ]
#       }
#     }
#   },
#   "updated": "2017-07-01T13:05:43.167Z",
#   "normalizations": [],
#   "name": "Default Configuration",
#   "created": "2017-07-01T13:05:43.167Z",
#   "configuration_id": "e613ba93-ee58-40a9-8be5-e042d38b586c",
#   "enrichments": [
#     {
#       "source_field": "text",
#       "destination_field": "enriched_text",
#       "enrichment": "alchemy_language",
#       "options": {
#         "quotations": true,
#         "extract": "keyword, entity, doc-sentiment, taxonomy, concept, relation",
#         "sentiment": true
#       }
#     }
#   ],
#   "description": "The configuration used by default when creating a new collection without specifying a configuration_id."
# }

# %% [markdown]
# There are 3 main configuration blocks that affect how input documents are processed:
#
# 1. **`conversions`**: How to convert documents in various formats (Word, PDF, HTML) and extract elements that indicate some structure (e.g. headings).
# 2. **`enrichments`**: What NLP output results are we interested in (keywords, entities, sentiment, etc.).
# 3. **`normalizations`**: Post-processing steps to be applied to the output. This can be left empty in most cases, unless you need the output to be normalized into a very specific format.
#
# _**Note**: The default configuration for an environment cannot be modified. If you need to change any of the options, you will need to create a new one, and then edit it. The easiest way to do this is using the service dashboard, which is described later._

# %% [markdown]
# ### Test your configuration
#
# It is a good idea to test your configuration on a small sample text before you apply it to a larger document collection.
#
# _**Note**: We have supplied a sample document (`data/sample.html`) containing the opening crawl text for Star Wars: Episode IV, but you are free to use a text of your choosing._
#
# **Q**: (optional) If you use your own sample text, provide a brief title and description below.
#
# **A**:

# %%
# Test configuration on some sample text
data_dir = "data"
filename = os.path.join(data_dir, "sample.html")
with open(filename, "r") as f:
    res = discovery.test_document(environment_id=env_id, configuration_id=cfg_id, fileinfo=f)
print(json.dumps(res, indent=2))
# Out:
# {
#   "status": "completed",
#   "original_media_type": "text/html",
#   "enriched_field_units": 1,
#   "snapshots": [
#     {
#       "step": "html_input",
#       "snapshot": {
#         "html": "<html>\n<head>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n</head>\n<body>\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body>"
#       }
#     },
#     {
#       "step": "html_output",
#       "snapshot": {
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n</head>\n<body>\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       }
#     },
#     {
#       "step": "json_output",
#       "snapshot": {
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "metadata": {}
#       }
#     },
#     {
#       "step": "json_normalizations_output",
#       "snapshot": {
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "metadata": {}
#       }
#     },
#     {
#       "step": "enrichments_output",
#       "snapshot": {
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "enriched_text": {
#           "status": "OK",
#           "docSentiment": {
#             "mixed": false,
#             "score": -0.575489,
#             "type": "negative"
#           },
#           "language": "english",
#           "taxonomy": [
#             {
#               "confident": false,
#               "score": 0.584247,
#               "label": "/art and entertainment/movies and tv/movies"
#             },
#             {
#               "confident": false,
#               "score": 0.517031,
#               "label": "/society/unrest and war"
#             },
#             {
#               "confident": false,
#               "score": 0.215561,
#               "label": "/law, govt and politics/armed forces/army"
#             }
#           ],
#           "relations": [
#             {
#               "action": {
#                 "text": "is",
#                 "verb": {
#                   "text": "be",
#                   "tense": "present"
#                 },
#                 "lemmatized": "be"
#               },
#               "subject": {
#                 "text": "It"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "civil war"
#                   },
#                   {
#                     "text": "period"
#                   }
#                 ],
#                 "text": "a period of civil war",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": -0.564509,
#                   "type": "negative"
#                 },
#                 "entities": [
#                   {
#                     "text": "civil war",
#                     "type": "FieldTerminology"
#                   }
#                 ]
#               },
#               "sentence": " It is a period of civil war."
#             },
#             {
#               "action": {
#                 "text": "have won",
#                 "verb": {
#                   "text": "win",
#                   "tense": "past"
#                 },
#                 "lemmatized": "have win"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Rebel spaceships"
#                   },
#                   {
#                     "text": "hidden base"
#                   }
#                 ],
#                 "text": "Rebel spaceships, striking from a hidden base,"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "victory"
#                   }
#                 ],
#                 "text": "their first victory"
#               },
#               "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire."
#             },
#             {
#               "action": {
#                 "text": "managed",
#                 "verb": {
#                   "text": "manage",
#                   "tense": "past"
#                 },
#                 "lemmatized": "manage"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ],
#                 "text": "Rebel spies"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "armored space station"
#                   },
#                   {
#                     "text": "ultimate weapon"
#                   },
#                   {
#                     "text": "secret plans"
#                   },
#                   {
#                     "text": "entire planet"
#                   }
#                 ],
#                 "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": -0.596586,
#                   "type": "negative"
#                 }
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#             },
#             {
#               "action": {
#                 "text": "managed to steal",
#                 "verb": {
#                   "text": "steal",
#                   "tense": "future"
#                 },
#                 "lemmatized": "manage to steal"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ],
#                 "text": "Rebel spies"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "secret plans"
#                   }
#                 ],
#                 "text": "secret plans"
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#             },
#             {
#               "action": {
#                 "text": "to destroy",
#                 "verb": {
#                   "text": "destroy",
#                   "tense": "future"
#                 },
#                 "lemmatized": "to destroy"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ],
#                 "text": "Rebel spies"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "entire planet"
#                   }
#                 ],
#                 "text": "an entire planet",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": 0.748639,
#                   "type": "positive"
#                 },
#                 "sentimentFromSubject": {
#                   "mixed": false,
#                   "score": -0.754579,
#                   "type": "negative"
#                 }
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#             },
#             {
#               "action": {
#                 "text": "Pursued",
#                 "verb": {
#                   "text": "Pursued",
#                   "tense": "past"
#                 },
#                 "lemmatized": "Pursued"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Empire"
#                   }
#                 ],
#                 "text": "by the Empire",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": 0.554106,
#                   "type": "positive"
#                 }
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "Princess Leia"
#                   }
#                 ],
#                 "text": "Princess Leia",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": 0.682563,
#                   "type": "positive"
#                 }
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#             },
#             {
#               "action": {
#                 "text": "can save",
#                 "verb": {
#                   "text": "save",
#                   "tense": "future"
#                 },
#                 "lemmatized": "can save"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "plans"
#                   }
#                 ],
#                 "text": "the stolen plans",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": -0.44097,
#                   "type": "negative"
#                 }
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "people"
#                   }
#                 ],
#                 "text": "her people"
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#             },
#             {
#               "action": {
#                 "text": "restore",
#                 "verb": {
#                   "text": "restore",
#                   "tense": "future"
#                 },
#                 "lemmatized": "restore"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "freedom"
#                   }
#                 ],
#                 "text": "freedom"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "galaxy"
#                   }
#                 ],
#                 "text": "to the galaxy",
#                 "sentimentFromSubject": {
#                   "mixed": false,
#                   "score": 0.698799,
#                   "type": "positive"
#                 }
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#             }
#           ],
#           "entities": [
#             {
#               "relevance": 0.972336,
#               "count": 1,
#               "type": "FieldTerminology",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.409172,
#                 "type": "negative"
#               },
#               "text": "civil war"
#             }
#           ],
#           "concepts": [
#             {
#               "website": "http://www.starwars.com/movies/episode-iv",
#               "text": "Star Wars Episode IV: A New Hope",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#               "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#               "relevance": 0.98887
#             },
#             {
#               "website": "http://www.starwars.com",
#               "yago": "http://yago-knowledge.org/resource/Star_Wars",
#               "text": "Star Wars",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#               "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#               "relevance": 0.985705
#             },
#             {
#               "relevance": 0.90639,
#               "text": "Rebel Alliance",
#               "yago": "http://yago-knowledge.org/resource/Rebel_Alliance",
#               "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#               "freebase": "http://rdf.freebase.com/ns/m.0nr1k"
#             },
#             {
#               "relevance": 0.805771,
#               "text": "Luke Skywalker",
#               "yago": "http://yago-knowledge.org/resource/Luke_Skywalker",
#               "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#               "freebase": "http://rdf.freebase.com/ns/m.0f1bg"
#             },
#             {
#               "relevance": 0.801062,
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "website": "http://www.starwars.com/movies/episode-v",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#               "freebase": "http://rdf.freebase.com/ns/m.0f3m1"
#             },
#             {
#               "relevance": 0.777337,
#               "text": "Darth Vader",
#               "yago": "http://yago-knowledge.org/resource/Darth_Vader",
#               "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#               "freebase": "http://rdf.freebase.com/ns/m.0f2y0"
#             },
#             {
#               "relevance": 0.77159,
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "website": "http://www.starwars.com/movies/episode-vi",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#               "freebase": "http://rdf.freebase.com/ns/m.0ddjy"
#             },
#             {
#               "relevance": 0.748553,
#               "text": "Grand Moff Tarkin",
#               "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin",
#               "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#               "freebase": "http://rdf.freebase.com/ns/m.0jrsz"
#             },
#             {
#               "relevance": 0.697065,
#               "text": "Star Wars Episode III: Revenge of the Sith",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#               "freebase": "http://rdf.freebase.com/ns/m.0fdv3"
#             },
#             {
#               "relevance": 0.607163,
#               "text": "Princess Leia Organa",
#               "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa",
#               "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa"
#             },
#             {
#               "relevance": 0.59271,
#               "text": "Death Star",
#               "yago": "http://yago-knowledge.org/resource/Death_Star",
#               "dbpedia": "http://dbpedia.org/resource/Death_Star",
#               "freebase": "http://rdf.freebase.com/ns/m.0f325"
#             },
#             {
#               "relevance": 0.543114,
#               "text": "Jabba the Hutt",
#               "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt",
#               "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#               "freebase": "http://rdf.freebase.com/ns/m.0fjms"
#             },
#             {
#               "relevance": 0.523169,
#               "text": "Galactic Empire",
#               "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)",
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#               "freebase": "http://rdf.freebase.com/ns/m.0hwyg"
#             },
#             {
#               "relevance": 0.519032,
#               "text": "Star Wars galaxy",
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy"
#             },
#             {
#               "website": "http://www.starwars.com/eu",
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#               "text": "Star Wars Expanded Universe",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#               "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#               "relevance": 0.507885
#             },
#             {
#               "relevance": 0.503196,
#               "text": "Alderaan",
#               "yago": "http://yago-knowledge.org/resource/Alderaan",
#               "dbpedia": "http://dbpedia.org/resource/Alderaan",
#               "freebase": "http://rdf.freebase.com/ns/m.065lhy"
#             },
#             {
#               "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#               "text": "Carrie Fisher",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA",
#               "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher",
#               "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#               "relevance": 0.481464
#             },
#             {
#               "yago": "http://yago-knowledge.org/resource/Jedi",
#               "text": "Jedi",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA",
#               "dbpedia": "http://dbpedia.org/resource/Jedi",
#               "freebase": "http://rdf.freebase.com/ns/m.045n4",
#               "relevance": 0.474365
#             },
#             {
#               "relevance": 0.4659,
#               "text": "The Star Wars Holiday Special",
#               "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special",
#               "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#               "freebase": "http://rdf.freebase.com/ns/m.0199wf"
#             },
#             {
#               "relevance": 0.46456,
#               "text": "Wedge Antilles",
#               "yago": "http://yago-knowledge.org/resource/Wedge_Antilles",
#               "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#               "freebase": "http://rdf.freebase.com/ns/m.0ddp_"
#             },
#             {
#               "relevance": 0.460469,
#               "text": "English-language films",
#               "dbpedia": "http://dbpedia.org/resource/English-language_films"
#             },
#             {
#               "relevance": 0.453766,
#               "text": "Padm\u00e9 Amidala",
#               "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala",
#               "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#               "freebase": "http://rdf.freebase.com/ns/m.0drf_"
#             },
#             {
#               "relevance": 0.447243,
#               "text": "Galactic Civil War",
#               "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War",
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6_"
#             },
#             {
#               "relevance": 0.436864,
#               "text": "Spaceballs",
#               "yago": "http://yago-knowledge.org/resource/Spaceballs",
#               "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#               "freebase": "http://rdf.freebase.com/ns/m.0j_nw"
#             },
#             {
#               "relevance": 0.43403,
#               "text": "Clone Wars",
#               "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)",
#               "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6n"
#             },
#             {
#               "relevance": 0.432345,
#               "text": "C-3PO",
#               "yago": "http://yago-knowledge.org/resource/C-3PO",
#               "dbpedia": "http://dbpedia.org/resource/C-3PO",
#               "freebase": "http://rdf.freebase.com/ns/m.0g_sv"
#             },
#             {
#               "relevance": 0.431988,
#               "text": "Obi-Wan Kenobi",
#               "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi",
#               "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#               "freebase": "http://rdf.freebase.com/ns/m.0fkm7"
#             },
#             {
#               "relevance": 0.430085,
#               "text": "R2-D2",
#               "yago": "http://yago-knowledge.org/resource/R2-D2",
#               "dbpedia": "http://dbpedia.org/resource/R2-D2",
#               "freebase": "http://rdf.freebase.com/ns/m.0g_rg"
#             }
#           ],
#           "keywords": [
#             {
#               "relevance": 0.920159,
#               "text": "Opening Crawl",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.785031,
#               "text": "New Hope",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.447888,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.775799,
#               "text": "Princess Leia races",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.40059,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.771384,
#               "text": "Star Wars",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.767527,
#               "text": "evil Galactic Empire",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.747615,
#               "text": "armored space station",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.494714,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.669776,
#               "text": "Rebel spaceships",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.656828,
#               "text": "Rebel spies",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.609404,
#               "text": "sinister agents",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.484685,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.600682,
#               "text": "civil war",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.409172,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.597836,
#               "text": "hidden base",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.488854,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.594694,
#               "text": "ultimate weapon",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.582765,
#               "text": "secret plans",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.582596,
#               "text": "entire planet",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.494714,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.574413,
#               "text": "DEATH STAR",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.430026,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.465394,
#               "text": "custodian",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.462247,
#               "text": "Episode",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.443969,
#               "text": "starship",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.40059,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.441799,
#               "text": "victory",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.437824,
#               "text": "galaxy",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.432092,
#               "text": "period",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.409172,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.429238,
#               "text": "battle",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.37594,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.428916,
#               "text": "home",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.40059,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.428498,
#               "text": "people",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             }
#           ]
#         },
#         "metadata": {}
#       }
#     },
#     {
#       "step": "normalizations_output",
#       "snapshot": {
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "enriched_text": {
#           "status": "OK",
#           "docSentiment": {
#             "mixed": false,
#             "score": -0.575489,
#             "type": "negative"
#           },
#           "language": "english",
#           "taxonomy": [
#             {
#               "confident": false,
#               "score": 0.584247,
#               "label": "/art and entertainment/movies and tv/movies"
#             },
#             {
#               "confident": false,
#               "score": 0.517031,
#               "label": "/society/unrest and war"
#             },
#             {
#               "confident": false,
#               "score": 0.215561,
#               "label": "/law, govt and politics/armed forces/army"
#             }
#           ],
#           "relations": [
#             {
#               "action": {
#                 "text": "is",
#                 "verb": {
#                   "text": "be",
#                   "tense": "present"
#                 },
#                 "lemmatized": "be"
#               },
#               "subject": {
#                 "text": "It"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "civil war"
#                   },
#                   {
#                     "text": "period"
#                   }
#                 ],
#                 "text": "a period of civil war",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": -0.564509,
#                   "type": "negative"
#                 },
#                 "entities": [
#                   {
#                     "text": "civil war",
#                     "type": "FieldTerminology"
#                   }
#                 ]
#               },
#               "sentence": " It is a period of civil war."
#             },
#             {
#               "action": {
#                 "text": "have won",
#                 "verb": {
#                   "text": "win",
#                   "tense": "past"
#                 },
#                 "lemmatized": "have win"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Rebel spaceships"
#                   },
#                   {
#                     "text": "hidden base"
#                   }
#                 ],
#                 "text": "Rebel spaceships, striking from a hidden base,"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "victory"
#                   }
#                 ],
#                 "text": "their first victory"
#               },
#               "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire."
#             },
#             {
#               "action": {
#                 "text": "managed",
#                 "verb": {
#                   "text": "manage",
#                   "tense": "past"
#                 },
#                 "lemmatized": "manage"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ],
#                 "text": "Rebel spies"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "armored space station"
#                   },
#                   {
#                     "text": "ultimate weapon"
#                   },
#                   {
#                     "text": "secret plans"
#                   },
#                   {
#                     "text": "entire planet"
#                   }
#                 ],
#                 "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": -0.596586,
#                   "type": "negative"
#                 }
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#             },
#             {
#               "action": {
#                 "text": "managed to steal",
#                 "verb": {
#                   "text": "steal",
#                   "tense": "future"
#                 },
#                 "lemmatized": "manage to steal"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ],
#                 "text": "Rebel spies"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "secret plans"
#                   }
#                 ],
#                 "text": "secret plans"
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#             },
#             {
#               "action": {
#                 "text": "to destroy",
#                 "verb": {
#                   "text": "destroy",
#                   "tense": "future"
#                 },
#                 "lemmatized": "to destroy"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ],
#                 "text": "Rebel spies"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "entire planet"
#                   }
#                 ],
#                 "text": "an entire planet",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": 0.748639,
#                   "type": "positive"
#                 },
#                 "sentimentFromSubject": {
#                   "mixed": false,
#                   "score": -0.754579,
#                   "type": "negative"
#                 }
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#             },
#             {
#               "action": {
#                 "text": "Pursued",
#                 "verb": {
#                   "text": "Pursued",
#                   "tense": "past"
#                 },
#                 "lemmatized": "Pursued"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "Empire"
#                   }
#                 ],
#                 "text": "by the Empire",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": 0.554106,
#                   "type": "positive"
#                 }
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "Princess Leia"
#                   }
#                 ],
#                 "text": "Princess Leia",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": 0.682563,
#                   "type": "positive"
#                 }
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#             },
#             {
#               "action": {
#                 "text": "can save",
#                 "verb": {
#                   "text": "save",
#                   "tense": "future"
#                 },
#                 "lemmatized": "can save"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "plans"
#                   }
#                 ],
#                 "text": "the stolen plans",
#                 "sentiment": {
#                   "mixed": false,
#                   "score": -0.44097,
#                   "type": "negative"
#                 }
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "people"
#                   }
#                 ],
#                 "text": "her people"
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#             },
#             {
#               "action": {
#                 "text": "restore",
#                 "verb": {
#                   "text": "restore",
#                   "tense": "future"
#                 },
#                 "lemmatized": "restore"
#               },
#               "subject": {
#                 "keywords": [
#                   {
#                     "text": "freedom"
#                   }
#                 ],
#                 "text": "freedom"
#               },
#               "object": {
#                 "keywords": [
#                   {
#                     "text": "galaxy"
#                   }
#                 ],
#                 "text": "to the galaxy",
#                 "sentimentFromSubject": {
#                   "mixed": false,
#                   "score": 0.698799,
#                   "type": "positive"
#                 }
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#             }
#           ],
#           "entities": [
#             {
#               "relevance": 0.972336,
#               "count": 1,
#               "type": "FieldTerminology",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.409172,
#                 "type": "negative"
#               },
#               "text": "civil war"
#             }
#           ],
#           "concepts": [
#             {
#               "website": "http://www.starwars.com/movies/episode-iv",
#               "text": "Star Wars Episode IV: A New Hope",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#               "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#               "relevance": 0.98887
#             },
#             {
#               "website": "http://www.starwars.com",
#               "yago": "http://yago-knowledge.org/resource/Star_Wars",
#               "text": "Star Wars",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#               "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#               "relevance": 0.985705
#             },
#             {
#               "relevance": 0.90639,
#               "text": "Rebel Alliance",
#               "yago": "http://yago-knowledge.org/resource/Rebel_Alliance",
#               "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#               "freebase": "http://rdf.freebase.com/ns/m.0nr1k"
#             },
#             {
#               "relevance": 0.805771,
#               "text": "Luke Skywalker",
#               "yago": "http://yago-knowledge.org/resource/Luke_Skywalker",
#               "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#               "freebase": "http://rdf.freebase.com/ns/m.0f1bg"
#             },
#             {
#               "relevance": 0.801062,
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "website": "http://www.starwars.com/movies/episode-v",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#               "freebase": "http://rdf.freebase.com/ns/m.0f3m1"
#             },
#             {
#               "relevance": 0.777337,
#               "text": "Darth Vader",
#               "yago": "http://yago-knowledge.org/resource/Darth_Vader",
#               "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#               "freebase": "http://rdf.freebase.com/ns/m.0f2y0"
#             },
#             {
#               "relevance": 0.77159,
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "website": "http://www.starwars.com/movies/episode-vi",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#               "freebase": "http://rdf.freebase.com/ns/m.0ddjy"
#             },
#             {
#               "relevance": 0.748553,
#               "text": "Grand Moff Tarkin",
#               "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin",
#               "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#               "freebase": "http://rdf.freebase.com/ns/m.0jrsz"
#             },
#             {
#               "relevance": 0.697065,
#               "text": "Star Wars Episode III: Revenge of the Sith",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#               "freebase": "http://rdf.freebase.com/ns/m.0fdv3"
#             },
#             {
#               "relevance": 0.607163,
#               "text": "Princess Leia Organa",
#               "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa",
#               "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa"
#             },
#             {
#               "relevance": 0.59271,
#               "text": "Death Star",
#               "yago": "http://yago-knowledge.org/resource/Death_Star",
#               "dbpedia": "http://dbpedia.org/resource/Death_Star",
#               "freebase": "http://rdf.freebase.com/ns/m.0f325"
#             },
#             {
#               "relevance": 0.543114,
#               "text": "Jabba the Hutt",
#               "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt",
#               "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#               "freebase": "http://rdf.freebase.com/ns/m.0fjms"
#             },
#             {
#               "relevance": 0.523169,
#               "text": "Galactic Empire",
#               "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)",
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#               "freebase": "http://rdf.freebase.com/ns/m.0hwyg"
#             },
#             {
#               "relevance": 0.519032,
#               "text": "Star Wars galaxy",
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy"
#             },
#             {
#               "website": "http://www.starwars.com/eu",
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#               "text": "Star Wars Expanded Universe",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#               "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#               "relevance": 0.507885
#             },
#             {
#               "relevance": 0.503196,
#               "text": "Alderaan",
#               "yago": "http://yago-knowledge.org/resource/Alderaan",
#               "dbpedia": "http://dbpedia.org/resource/Alderaan",
#               "freebase": "http://rdf.freebase.com/ns/m.065lhy"
#             },
#             {
#               "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#               "text": "Carrie Fisher",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA",
#               "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher",
#               "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#               "relevance": 0.481464
#             },
#             {
#               "yago": "http://yago-knowledge.org/resource/Jedi",
#               "text": "Jedi",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA",
#               "dbpedia": "http://dbpedia.org/resource/Jedi",
#               "freebase": "http://rdf.freebase.com/ns/m.045n4",
#               "relevance": 0.474365
#             },
#             {
#               "relevance": 0.4659,
#               "text": "The Star Wars Holiday Special",
#               "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special",
#               "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#               "freebase": "http://rdf.freebase.com/ns/m.0199wf"
#             },
#             {
#               "relevance": 0.46456,
#               "text": "Wedge Antilles",
#               "yago": "http://yago-knowledge.org/resource/Wedge_Antilles",
#               "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#               "freebase": "http://rdf.freebase.com/ns/m.0ddp_"
#             },
#             {
#               "relevance": 0.460469,
#               "text": "English-language films",
#               "dbpedia": "http://dbpedia.org/resource/English-language_films"
#             },
#             {
#               "relevance": 0.453766,
#               "text": "Padm\u00e9 Amidala",
#               "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala",
#               "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#               "freebase": "http://rdf.freebase.com/ns/m.0drf_"
#             },
#             {
#               "relevance": 0.447243,
#               "text": "Galactic Civil War",
#               "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War",
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6_"
#             },
#             {
#               "relevance": 0.436864,
#               "text": "Spaceballs",
#               "yago": "http://yago-knowledge.org/resource/Spaceballs",
#               "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#               "freebase": "http://rdf.freebase.com/ns/m.0j_nw"
#             },
#             {
#               "relevance": 0.43403,
#               "text": "Clone Wars",
#               "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)",
#               "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6n"
#             },
#             {
#               "relevance": 0.432345,
#               "text": "C-3PO",
#               "yago": "http://yago-knowledge.org/resource/C-3PO",
#               "dbpedia": "http://dbpedia.org/resource/C-3PO",
#               "freebase": "http://rdf.freebase.com/ns/m.0g_sv"
#             },
#             {
#               "relevance": 0.431988,
#               "text": "Obi-Wan Kenobi",
#               "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi",
#               "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#               "freebase": "http://rdf.freebase.com/ns/m.0fkm7"
#             },
#             {
#               "relevance": 0.430085,
#               "text": "R2-D2",
#               "yago": "http://yago-knowledge.org/resource/R2-D2",
#               "dbpedia": "http://dbpedia.org/resource/R2-D2",
#               "freebase": "http://rdf.freebase.com/ns/m.0g_rg"
#             }
#           ],
#           "keywords": [
#             {
#               "relevance": 0.920159,
#               "text": "Opening Crawl",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.785031,
#               "text": "New Hope",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.447888,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.775799,
#               "text": "Princess Leia races",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.40059,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.771384,
#               "text": "Star Wars",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.767527,
#               "text": "evil Galactic Empire",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.747615,
#               "text": "armored space station",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.494714,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.669776,
#               "text": "Rebel spaceships",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.656828,
#               "text": "Rebel spies",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.609404,
#               "text": "sinister agents",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.484685,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.600682,
#               "text": "civil war",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.409172,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.597836,
#               "text": "hidden base",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.488854,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.594694,
#               "text": "ultimate weapon",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.582765,
#               "text": "secret plans",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.582596,
#               "text": "entire planet",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.494714,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.574413,
#               "text": "DEATH STAR",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.430026,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.465394,
#               "text": "custodian",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.462247,
#               "text": "Episode",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.443969,
#               "text": "starship",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.40059,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.441799,
#               "text": "victory",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.437824,
#               "text": "galaxy",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             },
#             {
#               "relevance": 0.432092,
#               "text": "period",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.409172,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.429238,
#               "text": "battle",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.37594,
#                 "type": "negative"
#               }
#             },
#             {
#               "relevance": 0.428916,
#               "text": "home",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.40059,
#                 "type": "positive"
#               }
#             },
#             {
#               "relevance": 0.428498,
#               "text": "people",
#               "sentiment": {
#                 "mixed": false,
#                 "type": "neutral"
#               }
#             }
#           ]
#         },
#         "metadata": {}
#       }
#     }
#   ],
#   "notices": []
# }

# %% [markdown]
# ### Analyze test output
#
# The results returned by the service contain a _snapshot_ of the information extracted at each step of processing - document conversions, enrichments and normalizations. We are interested in the output of applying enrichments (`"enrichments_output"`) or after normalizing them (`"normalizations_output"`). These should be identical if no post-processing/normalizations were specified in the configuration.

# %%
# Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
print(json.dumps(output, indent=2))
# Out:
# {
#   "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#   "extracted_metadata": {
#     "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#   },
#   "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#   "enriched_text": {
#     "status": "OK",
#     "docSentiment": {
#       "mixed": false,
#       "score": -0.575489,
#       "type": "negative"
#     },
#     "language": "english",
#     "taxonomy": [
#       {
#         "confident": false,
#         "score": 0.584247,
#         "label": "/art and entertainment/movies and tv/movies"
#       },
#       {
#         "confident": false,
#         "score": 0.517031,
#         "label": "/society/unrest and war"
#       },
#       {
#         "confident": false,
#         "score": 0.215561,
#         "label": "/law, govt and politics/armed forces/army"
#       }
#     ],
#     "relations": [
#       {
#         "action": {
#           "text": "is",
#           "verb": {
#             "text": "be",
#             "tense": "present"
#           },
#           "lemmatized": "be"
#         },
#         "subject": {
#           "text": "It"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "civil war"
#             },
#             {
#               "text": "period"
#             }
#           ],
#           "text": "a period of civil war",
#           "sentiment": {
#             "mixed": false,
#             "score": -0.564509,
#             "type": "negative"
#           },
#           "entities": [
#             {
#               "text": "civil war",
#               "type": "FieldTerminology"
#             }
#           ]
#         },
#         "sentence": " It is a period of civil war."
#       },
#       {
#         "action": {
#           "text": "have won",
#           "verb": {
#             "text": "win",
#             "tense": "past"
#           },
#           "lemmatized": "have win"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spaceships"
#             },
#             {
#               "text": "hidden base"
#             }
#           ],
#           "text": "Rebel spaceships, striking from a hidden base,"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "victory"
#             }
#           ],
#           "text": "their first victory"
#         },
#         "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire."
#       },
#       {
#         "action": {
#           "text": "managed",
#           "verb": {
#             "text": "manage",
#             "tense": "past"
#           },
#           "lemmatized": "manage"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ],
#           "text": "Rebel spies"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "armored space station"
#             },
#             {
#               "text": "ultimate weapon"
#             },
#             {
#               "text": "secret plans"
#             },
#             {
#               "text": "entire planet"
#             }
#           ],
#           "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#           "sentiment": {
#             "mixed": false,
#             "score": -0.596586,
#             "type": "negative"
#           }
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#       },
#       {
#         "action": {
#           "text": "managed to steal",
#           "verb": {
#             "text": "steal",
#             "tense": "future"
#           },
#           "lemmatized": "manage to steal"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ],
#           "text": "Rebel spies"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "secret plans"
#             }
#           ],
#           "text": "secret plans"
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#       },
#       {
#         "action": {
#           "text": "to destroy",
#           "verb": {
#             "text": "destroy",
#             "tense": "future"
#           },
#           "lemmatized": "to destroy"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ],
#           "text": "Rebel spies"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "entire planet"
#             }
#           ],
#           "text": "an entire planet",
#           "sentiment": {
#             "mixed": false,
#             "score": 0.748639,
#             "type": "positive"
#           },
#           "sentimentFromSubject": {
#             "mixed": false,
#             "score": -0.754579,
#             "type": "negative"
#           }
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet."
#       },
#       {
#         "action": {
#           "text": "Pursued",
#           "verb": {
#             "text": "Pursued",
#             "tense": "past"
#           },
#           "lemmatized": "Pursued"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "Empire"
#             }
#           ],
#           "text": "by the Empire",
#           "sentiment": {
#             "mixed": false,
#             "score": 0.554106,
#             "type": "positive"
#           }
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "Princess Leia"
#             }
#           ],
#           "text": "Princess Leia",
#           "sentiment": {
#             "mixed": false,
#             "score": 0.682563,
#             "type": "positive"
#           }
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       },
#       {
#         "action": {
#           "text": "can save",
#           "verb": {
#             "text": "save",
#             "tense": "future"
#           },
#           "lemmatized": "can save"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "plans"
#             }
#           ],
#           "text": "the stolen plans",
#           "sentiment": {
#             "mixed": false,
#             "score": -0.44097,
#             "type": "negative"
#           }
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "people"
#             }
#           ],
#           "text": "her people"
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       },
#       {
#         "action": {
#           "text": "restore",
#           "verb": {
#             "text": "restore",
#             "tense": "future"
#           },
#           "lemmatized": "restore"
#         },
#         "subject": {
#           "keywords": [
#             {
#               "text": "freedom"
#             }
#           ],
#           "text": "freedom"
#         },
#         "object": {
#           "keywords": [
#             {
#               "text": "galaxy"
#             }
#           ],
#           "text": "to the galaxy",
#           "sentimentFromSubject": {
#             "mixed": false,
#             "score": 0.698799,
#             "type": "positive"
#           }
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       }
#     ],
#     "entities": [
#       {
#         "relevance": 0.972336,
#         "count": 1,
#         "type": "FieldTerminology",
#         "sentiment": {
#           "mixed": false,
#           "score": -0.409172,
#           "type": "negative"
#         },
#         "text": "civil war"
#       }
#     ],
#     "concepts": [
#       {
#         "website": "http://www.starwars.com/movies/episode-iv",
#         "text": "Star Wars Episode IV: A New Hope",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#         "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#         "relevance": 0.98887
#       },
#       {
#         "website": "http://www.starwars.com",
#         "yago": "http://yago-knowledge.org/resource/Star_Wars",
#         "text": "Star Wars",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#         "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#         "relevance": 0.985705
#       },
#       {
#         "relevance": 0.90639,
#         "text": "Rebel Alliance",
#         "yago": "http://yago-knowledge.org/resource/Rebel_Alliance",
#         "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#         "freebase": "http://rdf.freebase.com/ns/m.0nr1k"
#       },
#       {
#         "relevance": 0.805771,
#         "text": "Luke Skywalker",
#         "yago": "http://yago-knowledge.org/resource/Luke_Skywalker",
#         "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#         "freebase": "http://rdf.freebase.com/ns/m.0f1bg"
#       },
#       {
#         "relevance": 0.801062,
#         "text": "Star Wars Episode V: The Empire Strikes Back",
#         "website": "http://www.starwars.com/movies/episode-v",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#         "freebase": "http://rdf.freebase.com/ns/m.0f3m1"
#       },
#       {
#         "relevance": 0.777337,
#         "text": "Darth Vader",
#         "yago": "http://yago-knowledge.org/resource/Darth_Vader",
#         "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#         "freebase": "http://rdf.freebase.com/ns/m.0f2y0"
#       },
#       {
#         "relevance": 0.77159,
#         "text": "Star Wars Episode VI: Return of the Jedi",
#         "website": "http://www.starwars.com/movies/episode-vi",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#         "freebase": "http://rdf.freebase.com/ns/m.0ddjy"
#       },
#       {
#         "relevance": 0.748553,
#         "text": "Grand Moff Tarkin",
#         "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin",
#         "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#         "freebase": "http://rdf.freebase.com/ns/m.0jrsz"
#       },
#       {
#         "relevance": 0.697065,
#         "text": "Star Wars Episode III: Revenge of the Sith",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#         "freebase": "http://rdf.freebase.com/ns/m.0fdv3"
#       },
#       {
#         "relevance": 0.607163,
#         "text": "Princess Leia Organa",
#         "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa",
#         "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa"
#       },
#       {
#         "relevance": 0.59271,
#         "text": "Death Star",
#         "yago": "http://yago-knowledge.org/resource/Death_Star",
#         "dbpedia": "http://dbpedia.org/resource/Death_Star",
#         "freebase": "http://rdf.freebase.com/ns/m.0f325"
#       },
#       {
#         "relevance": 0.543114,
#         "text": "Jabba the Hutt",
#         "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt",
#         "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#         "freebase": "http://rdf.freebase.com/ns/m.0fjms"
#       },
#       {
#         "relevance": 0.523169,
#         "text": "Galactic Empire",
#         "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)",
#         "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#         "freebase": "http://rdf.freebase.com/ns/m.0hwyg"
#       },
#       {
#         "relevance": 0.519032,
#         "text": "Star Wars galaxy",
#         "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy"
#       },
#       {
#         "website": "http://www.starwars.com/eu",
#         "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#         "text": "Star Wars Expanded Universe",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#         "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#         "relevance": 0.507885
#       },
#       {
#         "relevance": 0.503196,
#         "text": "Alderaan",
#         "yago": "http://yago-knowledge.org/resource/Alderaan",
#         "dbpedia": "http://dbpedia.org/resource/Alderaan",
#         "freebase": "http://rdf.freebase.com/ns/m.065lhy"
#       },
#       {
#         "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#         "text": "Carrie Fisher",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA",
#         "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher",
#         "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#         "relevance": 0.481464
#       },
#       {
#         "yago": "http://yago-knowledge.org/resource/Jedi",
#         "text": "Jedi",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA",
#         "dbpedia": "http://dbpedia.org/resource/Jedi",
#         "freebase": "http://rdf.freebase.com/ns/m.045n4",
#         "relevance": 0.474365
#       },
#       {
#         "relevance": 0.4659,
#         "text": "The Star Wars Holiday Special",
#         "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special",
#         "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#         "freebase": "http://rdf.freebase.com/ns/m.0199wf"
#       },
#       {
#         "relevance": 0.46456,
#         "text": "Wedge Antilles",
#         "yago": "http://yago-knowledge.org/resource/Wedge_Antilles",
#         "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#         "freebase": "http://rdf.freebase.com/ns/m.0ddp_"
#       },
#       {
#         "relevance": 0.460469,
#         "text": "English-language films",
#         "dbpedia": "http://dbpedia.org/resource/English-language_films"
#       },
#       {
#         "relevance": 0.453766,
#         "text": "Padm\u00e9 Amidala",
#         "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala",
#         "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#         "freebase": "http://rdf.freebase.com/ns/m.0drf_"
#       },
#       {
#         "relevance": 0.447243,
#         "text": "Galactic Civil War",
#         "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War",
#         "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#         "freebase": "http://rdf.freebase.com/ns/m.01qc6_"
#       },
#       {
#         "relevance": 0.436864,
#         "text": "Spaceballs",
#         "yago": "http://yago-knowledge.org/resource/Spaceballs",
#         "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#         "freebase": "http://rdf.freebase.com/ns/m.0j_nw"
#       },
#       {
#         "relevance": 0.43403,
#         "text": "Clone Wars",
#         "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)",
#         "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#         "freebase": "http://rdf.freebase.com/ns/m.01qc6n"
#       },
#       {
#         "relevance": 0.432345,
#         "text": "C-3PO",
#         "yago": "http://yago-knowledge.org/resource/C-3PO",
#         "dbpedia": "http://dbpedia.org/resource/C-3PO",
#         "freebase": "http://rdf.freebase.com/ns/m.0g_sv"
#       },
#       {
#         "relevance": 0.431988,
#         "text": "Obi-Wan Kenobi",
#         "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi",
#         "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#         "freebase": "http://rdf.freebase.com/ns/m.0fkm7"
#       },
#       {
#         "relevance": 0.430085,
#         "text": "R2-D2",
#         "yago": "http://yago-knowledge.org/resource/R2-D2",
#         "dbpedia": "http://dbpedia.org/resource/R2-D2",
#         "freebase": "http://rdf.freebase.com/ns/m.0g_rg"
#       }
#     ],
#     "keywords": [
#       {
#         "relevance": 0.920159,
#         "text": "Opening Crawl",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.785031,
#         "text": "New Hope",
#         "sentiment": {
#           "mixed": false,
#           "score": 0.447888,
#           "type": "positive"
#         }
#       },
#       {
#         "relevance": 0.775799,
#         "text": "Princess Leia races",
#         "sentiment": {
#           "mixed": false,
#           "score": 0.40059,
#           "type": "positive"
#         }
#       },
#       {
#         "relevance": 0.771384,
#         "text": "Star Wars",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.767527,
#         "text": "evil Galactic Empire",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.747615,
#         "text": "armored space station",
#         "sentiment": {
#           "mixed": false,
#           "score": -0.494714,
#           "type": "negative"
#         }
#       },
#       {
#         "relevance": 0.669776,
#         "text": "Rebel spaceships",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.656828,
#         "text": "Rebel spies",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.609404,
#         "text": "sinister agents",
#         "sentiment": {
#           "mixed": false,
#           "score": 0.484685,
#           "type": "positive"
#         }
#       },
#       {
#         "relevance": 0.600682,
#         "text": "civil war",
#         "sentiment": {
#           "mixed": false,
#           "score": -0.409172,
#           "type": "negative"
#         }
#       },
#       {
#         "relevance": 0.597836,
#         "text": "hidden base",
#         "sentiment": {
#           "mixed": false,
#           "score": 0.488854,
#           "type": "positive"
#         }
#       },
#       {
#         "relevance": 0.594694,
#         "text": "ultimate weapon",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.582765,
#         "text": "secret plans",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.582596,
#         "text": "entire planet",
#         "sentiment": {
#           "mixed": false,
#           "score": -0.494714,
#           "type": "negative"
#         }
#       },
#       {
#         "relevance": 0.574413,
#         "text": "DEATH STAR",
#         "sentiment": {
#           "mixed": false,
#           "score": -0.430026,
#           "type": "negative"
#         }
#       },
#       {
#         "relevance": 0.465394,
#         "text": "custodian",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.462247,
#         "text": "Episode",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.443969,
#         "text": "starship",
#         "sentiment": {
#           "mixed": false,
#           "score": 0.40059,
#           "type": "positive"
#         }
#       },
#       {
#         "relevance": 0.441799,
#         "text": "victory",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.437824,
#         "text": "galaxy",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       },
#       {
#         "relevance": 0.432092,
#         "text": "period",
#         "sentiment": {
#           "mixed": false,
#           "score": -0.409172,
#           "type": "negative"
#         }
#       },
#       {
#         "relevance": 0.429238,
#         "text": "battle",
#         "sentiment": {
#           "mixed": false,
#           "score": -0.37594,
#           "type": "negative"
#         }
#       },
#       {
#         "relevance": 0.428916,
#         "text": "home",
#         "sentiment": {
#           "mixed": false,
#           "score": 0.40059,
#           "type": "positive"
#         }
#       },
#       {
#         "relevance": 0.428498,
#         "text": "people",
#         "sentiment": {
#           "mixed": false,
#           "type": "neutral"
#         }
#       }
#     ]
#   },
#   "metadata": {}
# }

# %% [markdown]
# Answer the following questions based on the output above. Note that it contains the input HTML, extracted text and metadata as well as the actual enrichment results (`"enriched_text"` block).
#
# #### Sentiment
#
# **Q**: What is the overall sentiment detected in this text? Mention the `type` (positive/negative) and `score`.<br />
# (_Hint: Look for the `"docSentiment"` key in the output._)
#
# **A**:
# overall sentiment is negative with a score -0.575489
#
# #### Concepts
#
# **Q**: List 3 concepts that have been identified with a relevance > 0.5. Note that not all concepts here may be present directly in the text, some may have been inferred by Watson.<br />
# (_Hint: Look for `"concepts"`._)
#
# **A**:
#  - "Star Wars Episode IV: A New Hope"
#  - "Luke Skywalker"
#  - "Star Wars Episode V: The Empire Strikes Back"
#
#
# #### Relations
#
# Each relation is essentially a deeper analysis of a sentence (or part of a sentence). Here is a sample relation:
# ```json
# {
#   "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#   "subject": {
#     "text": "Rebel spies",
#     "keywords": [
#       {
#         "text": "Rebel spies"
#       }
#     ]
#   },
#   "action": {
#     "text": "managed to steal",
#     "lemmatized": "manage to steal",
#     "verb": {
#       "text": "steal",
#       "tense": "future"
#     }
#   },
#   "object": {
#     "text": "secret plans",
#     "keywords": [
#       {
#         "text": "secret plans"
#       }
#     ]
#   }
#  }
# ```
#
# In this case, Watson seems to have done a pretty good job of extracting some meaning from the sentence.
#
# **Q**: Find a relation where the extracted meaning is not as accurate, or not what you would've expected. List the `sentence`, `subject`, `action` and `object` parts as identified, and what you would've marked instead.<br />
# (_Hint: Look for `"relations"`._)
#
# **A**:
# ```json
# A: { "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.", "subject": { "keywords": [ { "text": "Rebel spies" } ], "text": "Rebel spies" }, "action": { "verb": { "text": "destroy", "tense": "future" }, "text": "to destroy", "lemmatized": "to destroy" }, "object": { "sentimentFromSubject": { "score": -0.754579, "mixed": false, "type": "negative" }, "sentiment": { "score": 0.748639, "mixed": false, "type": "positive" }, "text": "an entire planet", "keywords": [ { "text": "entire planet" } ] } },
#   In this example, action of destroying an entire planet has been related to Rebel spies in a sense that they want to destroy the planet. However, ability of destroying the planet is actually refering to Death Star, so the correct keyword in above relation would have been DEATH STAR and not Rebel spies.
# ```
# As I understand from the example above, the keyword should be DEATH STAR instead of Rebel Spies. From this sentence *the DEATH STAR, an armored space station with enough power to destroy an entire planet*, we can see that the ability of destroying the planet is referring to DEAT STAR.
# #### Keywords
#
# You may have noticed that Watson identifies some `"keywords"` in the relations, e.g. `"Rebel spies"` and `"secret plans"` in the Star Wars example above. The output also contains a list of all keywords at the top level, for your convenience, along with their relevance to the document and sentiment conveyed. Let's visualize these keywords as a word cloud!
#
# Note: We'll be using this handy [worldcoud library](https://github.com/amueller/word_cloud) to generate the visualization. So you will need to install it first:
# ```bash
# pip install wordcloud
# ```

# %%
# Visualize keywords by relevance as a wordcloud
from wordcloud import WordCloud

wc_data = { w["text"]: w["relevance"] for w in output["enriched_text"]["keywords"] }
wc = WordCloud(width=400, height=300, scale=2, background_color="white")
wc.generate_from_frequencies(wc_data)  # use precomputed relevance instead of frequencies

plt.figure(figsize=(4, 3), dpi=200)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# Feel free to play with this visualization and improve it. What about using a different metric instead of relevance, e.g. direct word frequencies that the wordcloud library computes by default?
#
# #### Other results
#
# Watson's output also includes processed results from other enrichments that were applied to the text, including entities and taxonomy (what topic or category does this text relate to).
#
# ```json
# "taxonomy": [
#   {
#     "label": "/art and entertainment/movies and tv/movies",
#     "score": 0.584247,
#     "confident": false
#   },
#   {
#     "label": "/society/unrest and war",
#     "score": 0.517031,
#     "confident": false
#   },
#   {
#     "confident": false,
#     "label": "/law, govt and politics/armed forces/army",
#     "score": 0.215561
#   }
# ],
# ```
#
# Get a good sense of all the different pieces of information available in the results. Start thinking about which ones will be useful for looking up answers to questions, and how you might use them.

# %% [markdown]
# ## 2. Ingest documents
#
# ### Create a collection
#
# A _collection_ is used to organize documents of the same kind. For instance, you may want to create a collection of book reviews, or a collection of Wikipedia articles, but it may not make much sense to mix the two groups. This allows Watson to make meaningful inferences over the set of documents, find commonalities and identify important concepts.
#
# Let's create one called "Story Chunks".

# %%
# Prepare a collection of documents to use
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id,
    create=True, create_args=dict(
        environment_id=env_id, configuration_id=cfg_id,
        description="Stories and plots split up into chunks suitable for answering"
    ))
print(json.dumps(col, indent=2))
# Out:
# Created collection: Story Chunks (122cfe90-6880-41b5-a42d-31821afd34bd)
# {
#   "status": "active",
#   "updated": "2017-07-10T14:56:28.457Z",
#   "name": "Story Chunks",
#   "language": "en",
#   "created": "2017-07-10T14:56:28.457Z",
#   "configuration_id": "e613ba93-ee58-40a9-8be5-e042d38b586c",
#   "collection_id": "122cfe90-6880-41b5-a42d-31821afd34bd",
#   "description": "Stories and plots split up into chunks suitable for answering"
# }

# %% [markdown]
# Once you have created a collection, you should be able to view it using the Discovery Service tool. To open, go to the **Manage** tab for your service instance, and click the **Launch tool** button.
#
# <img src="images/discovery-manage.png" alt="Discovery service - Manage tab" width="800" />

# %% [markdown]
# Here you should see the "Story Chunks" collection you just created.
#
# <img src="images/discovery-tooling.png" alt="Discovery service - Tool showing collections" width="800" />
#
# You can open the collection to view more details about it. If you need to modify configuration options, click the **Switch** link and create a new configuration (the default one cannot be changed).

# %% [markdown]
# ### Add documents
#
# Okay, now that we have everything set up, let's add a set of "documents" we want Watson to look up answers from, using the Python SDK. Note that Watson treats each "document" as a unit of text that is returned as the result of a query. But we want to retrieve a paragraph of text for each question. So, let's split each file up into individual paragraphs. We will use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library for this purpose.
#
# _**Note**: You could also add and manage documents in the collection using the Discovery tool, but you would have to split paragraphs up into separate files._
#
# _**Note**: We have provided a set of files (`data/Star-Wars/*.html`) with summary plots for Star Wars movies, but you are free to use a collection of your choice. Open one of the files in a text editor to see how the paragraphs are delimited using `<p>...</p>` tags - this is how the code block below split paragraphs into separate "documents"._

# %%
# Add documents to collection
doc_ids = []  # to store the generated id for each document added
for filename in glob.glob(os.path.join(data_dir, "Star-Wars", "*.html")):
    print("Adding file:", filename)
    with open(filename, "r") as f:
        # Split each individual <p> into its own "document"
        doc = f.read()
        soup = BeautifulSoup(doc, 'html.parser')
        for i, p in enumerate(soup.find_all('p')):
            doc_info = discovery.add_document(environment_id=env_id, collection_id=col_id,
                file_data=json.dumps({"text": p.get_text(strip=True)}),
                mime_type="application/json",
                metadata={"title": soup.title.get_text(strip=True)})
            doc_ids.append(doc_info["document_id"])
print("Total", len(doc_ids), "documents added.")
# Out:
# ('Adding file:', 'data/Star-Wars/Episode-I_The-Phantom-Menace.html')
# ('Adding file:', 'data/Star-Wars/Episode-II_Attack-of-the-Clones.html')
# ('Adding file:', 'data/Star-Wars/Episode-III_Revenge-of-the-Sith.html')
# ('Adding file:', 'data/Star-Wars/Episode-IV_A-New-Hope.html')
# ('Adding file:', 'data/Star-Wars/Episode-V_The-Empire-Strikes-Back.html')
# ('Adding file:', 'data/Star-Wars/Episode-VI_Return-of-the-Jedi.html')
# ('Adding file:', 'data/Star-Wars/Episode-VII_The-Force-Awakens.html')
# ('Adding file:', 'data/Star-Wars/Rogue-One.html')
# ('Total', 42, 'documents added.')

# %% [markdown]
# If you look at the collection details, you may notice that the `"document_counts"` field now shows some documents as `available` or `processing`. Once processing is complete, you should see all the documents under the `available` count.

# %%
# View collection details to verify all documents have been processed
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id)
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (122cfe90-6880-41b5-a42d-31821afd34bd)
# {
#   "status": "active",
#   "updated": "2017-07-10T14:56:28.457Z",
#   "name": "Story Chunks",
#   "language": "en",
#   "created": "2017-07-10T14:56:28.457Z",
#   "document_counts": {
#     "available": 42,
#     "failed": 0,
#     "processing": 0
#   },
#   "configuration_id": "e613ba93-ee58-40a9-8be5-e042d38b586c",
#   "training_status": {
#     "available": false,
#     "successfully_trained": "",
#     "total_examples": 0,
#     "processing": false,
#     "sufficient_label_diversity": false,
#     "minimum_examples_added": false,
#     "notices": 0,
#     "minimum_queries_added": false,
#     "data_updated": ""
#   },
#   "collection_id": "122cfe90-6880-41b5-a42d-31821afd34bd",
#   "description": "Stories and plots split up into chunks suitable for answering"
# }

# %% [markdown]
# So, what did the Discovery service learn? If you list the fields extracted from the set of documents in the collection as part of the enrichment process, you'll see familiar fields like `concepts`, `entities` and `keywords` that were returned in the test analysis.

# %%
# List all fields extracted
discovery.list_collection_fields(environment_id=env_id, collection_id=col_id)
# Out:
# {u'fields': [{u'field': u'122cfe90-6880-41b5-a42d-31821afd34bd.mappings.document._all.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text', u'type': u'nested'},
#   {u'field': u'extracted_metadata', u'type': u'nested'},
#   {u'field': u'metadata', u'type': u'nested'},
#   {u'field': u'text', u'type': u'string'},
#   {u'field': u'text.analyzer', u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts', u'type': u'nested'},
#   {u'field': u'enriched_text.properties.docSentiment', u'type': u'nested'},
#   {u'field': u'enriched_text.properties.entities', u'type': u'nested'},
#   {u'field': u'enriched_text.properties.keywords', u'type': u'nested'},
#   {u'field': u'enriched_text.properties.language', u'type': u'string'},
#   {u'field': u'enriched_text.properties.language.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations', u'type': u'nested'},
#   {u'field': u'enriched_text.properties.status', u'type': u'string'},
#   {u'field': u'enriched_text.properties.status.analyzer', u'type': u'english'},
#   {u'field': u'enriched_text.properties.taxonomy', u'type': u'nested'},
#   {u'field': u'extracted_metadata.properties.file_type', u'type': u'string'},
#   {u'field': u'extracted_metadata.properties.file_type.analyzer',
#    u'type': u'english'},
#   {u'field': u'extracted_metadata.properties.filename', u'type': u'string'},
#   {u'field': u'extracted_metadata.properties.filename.analyzer',
#    u'type': u'english'},
#   {u'field': u'extracted_metadata.properties.sha1', u'type': u'string'},
#   {u'field': u'extracted_metadata.properties.sha1.analyzer',
#    u'type': u'english'},
#   {u'field': u'metadata.properties.title', u'type': u'string'},
#   {u'field': u'metadata.properties.title.analyzer', u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.ciaFactbook',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.ciaFactbook.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.dbpedia',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.dbpedia.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.freebase',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.freebase.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.geo',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.geo.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.musicBrainz',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.musicBrainz.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.opencyc',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.opencyc.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.relevance',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.concepts.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.website',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.website.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.concepts.properties.yago',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.concepts.properties.yago.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.docSentiment.properties.mixed',
#    u'type': u'boolean'},
#   {u'field': u'enriched_text.properties.docSentiment.properties.score',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.docSentiment.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.docSentiment.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.entities.properties.count',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.entities.properties.relevance',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.entities.properties.sentiment',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.entities.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.entities.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.entities.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.entities.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.keywords.properties.relevance',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.keywords.properties.sentiment',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.keywords.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.keywords.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.action',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.location',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.object',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.sentence',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.sentence.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.taxonomy.properties.confident',
#    u'type': u'boolean'},
#   {u'field': u'enriched_text.properties.taxonomy.properties.label',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.taxonomy.properties.label.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.taxonomy.properties.score',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated.properties.dbpedia',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated.properties.freebase',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated.properties.name',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated.properties.name.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated.properties.yago',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.entities.properties.sentiment.properties.mixed',
#    u'type': u'boolean'},
#   {u'field': u'enriched_text.properties.entities.properties.sentiment.properties.score',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.entities.properties.sentiment.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.entities.properties.sentiment.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.keywords.properties.sentiment.properties.mixed',
#    u'type': u'boolean'},
#   {u'field': u'enriched_text.properties.keywords.properties.sentiment.properties.score',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.keywords.properties.sentiment.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.keywords.properties.sentiment.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.lemmatized',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.lemmatized.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.verb',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.sentiment',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.keywords',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentiment',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.keywords',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.sentiment',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.verb.properties.tense',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.verb.properties.tense.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.verb.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.action.properties.verb.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.sentiment.properties.score',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.sentiment.properties.score.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.sentiment.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.sentiment.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.keywords.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.keywords.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentiment.properties.mixed',
#    u'type': u'boolean'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentiment.properties.score',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentiment.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentiment.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.mixed',
#    u'type': u'boolean'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.score',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated',
#    u'type': u'nested'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.keywords.properties.text',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.keywords.properties.text.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.mixed',
#    u'type': u'boolean'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.score',
#    u'type': u'double'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.type',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.type.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.dbpedia',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.freebase',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.name',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.name.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.yago',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.dbpedia',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.freebase',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.name',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.name.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.yago',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.dbpedia',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.freebase',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.name',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.name.analyzer',
#    u'type': u'english'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.yago',
#    u'type': u'string'},
#   {u'field': u'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    u'type': u'english'}]}

# %% [markdown]
# ### Test query
#
# Let's perform a simple query to see if the service can fetch the proper document for us:
# > _Look for all paragraphs that have a relation (sentence) with "Jar Jar" as the subject, and return the title and text._

# %%
# A simple query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.relations.subject.text:\"Jar Jar\"",
        "return": "metadata.title,text"
    })
print(json.dumps(results, indent=2))
# Out:
# {
#   "matching_results": 2,
#   "results": [
#     {
#       "text": "Supreme Chancellor Valorum, leader of the Galactic Republic, dispatches Jedi Knight Qui-Gon Jinn and his apprentice, Obi-Wan Kenobi, to negotiate with the Trade Federation leadership to end a blockade of battleships around the planet Naboo. Darth Sidious, a Sith Lord and the Trade Federation's secret adviser, orders Federation Viceroy Nute Gunray to kill the Jedi and invade Naboo with an army of battle droids. The Jedi escape and flee to Naboo, where Qui-Gon saves a Gungan outcast, Jar Jar Binks, from being run over and killed by a droid tank during the invasion. Indebted to the Jedi, Jar Jar leads them to an underwater Gungan city. The Jedi unsuccessfully try to persuade the Gungan leader, Boss Nass, into helping the people of Naboo, though they are able to obtain transportation to Theed, the capital city on the surface. They rescue Queen Amidala, the ruler of the Naboo people, and escape the planet on her royal starship, which is damaged as they pass the Federation blockade.",
#       "score": 2.9905405,
#       "id": "e3e952aa-9962-4ea4-b67e-fbc708ed0b08",
#       "metadata": {
#         "title": "Star Wars: Episode I - The Phantom Menace"
#       }
#     },
#     {
#       "text": "Amidala's ship is unable to sustain its hyperdrive and lands for repairs on the desert planet Tatooine. Qui-Gon, Jar Jar, astromech droid R2-D2, and Amidala (in disguise as the handmaiden Padm\u00e9) visit the settlement of Mos Espa to buy new parts at a junk shop. They meet the shop's owner Watto and his nine-year-old slave, Anakin Skywalker, who is a gifted pilot and engineer and has created a protocol droid called C-3PO. Qui-Gon senses a strong presence of the Force within Anakin and is convinced that he is the \"chosen one\" of Jedi prophecy who will bring balance to the Force. Qui-Gon wagers Anakin's freedom with Watto in a Podrace, which Anakin wins. Anakin joins the group to be trained as a Jedi, leaving his mother Shmi behind. En route to their starship, Qui-Gon briefly duels with Darth Maul, Darth Sidious's apprentice, who was sent to capture Amidala. Qui-Gon quits the duel and escapes by leaping onto the open boarding ramp of the departing starship.",
#       "score": 2.1361003,
#       "id": "53478e44-bdfe-4898-91d3-db3f50a70394",
#       "metadata": {
#         "title": "Star Wars: Episode I - The Phantom Menace"
#       }
#     }
#   ]
# }

# %%
# my query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.relations.subject.text:\"Princess Leia\"",
        "return": "metadata.title,text"
    })
print(json.dumps(results, indent=2))
# Out:
# {
#   "matching_results": 3,
#   "results": [
#     {
#       "text": "The Rebel fleet prepares to jump to hyperspace but are intercepted by Vader's flagship. Vader invades the command ship and kills many rebels in his pursuit of the schematics, but a small starship escapes with them on board. Aboard the fleeing ship, Princess Leia declares that the schematics will provide hope for the Rebellion.",
#       "score": 5.862092,
#       "id": "70a24bdc-5966-4acb-b487-6c57d5750191",
#       "metadata": {
#         "title": "Star Wars: Rogue One"
#       }
#     },
#     {
#       "text": "The galaxy is in the midst of a civil war. Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet. Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader. Before she is captured, Leia hides the plans in the memory of an astromech droid, R2-D2, along with a holographic recording. R2-D2 flees to the surface of the desert planet Tatooine with C-3PO, a protocol droid.",
#       "score": 2.931046,
#       "id": "01d36fb9-08ae-4912-aa3b-98afa552de52",
#       "metadata": {
#         "title": "Star Wars: Episode IV - A New Hope"
#       }
#     },
#     {
#       "text": "Three years after the destruction of the Death Star, the Rebel Alliance has been driven from their former base on Yavin IV by the Galactic Empire. The Rebels, led by Princess Leia, have set up their new base on the ice planet Hoth. The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels\u2019 new base by dispatching probe droids across the galaxy.",
#       "score": 2.931046,
#       "id": "3725409d-4d53-4591-86f6-66d697df293e",
#       "metadata": {
#         "title": "Star Wars: Episode V - The Empire Strikes Back"
#       }
#     }
#   ]
# }

# %% [markdown]
# Change the above query and see what results you get! Try to find one that returns relevant results, and keep that (along with the output) for review.
#
# > See [Query building reference](https://www.ibm.com/watson/developercloud/doc/discovery/query-reference.html) for descriptions of all possible parameters, operators and aggregations. You can also choose to build the query using the web interface (click the "Story Chunks" collection to query it), and then reproduce the query here.
#
# Then answer the questions below:
#
# **Q**: What query did you try? Express it in plain words below.
#
# **A**:
# Princess Leia
#
# **Q**: What answer did you get back from Watson? You only need to mention the relevant snippet of text fro mthe paragraph(s) returned.
#
# **A**:
# ***The Rebel fleet prepares to jump to hyperspace but are intercepted by Vader's flagship. Vader invades the command ship and kills many rebels in his pursuit of the schematics, but a small starship escapes with them on board. Aboard the fleeing ship, Princess Leia declares that the schematics will provide hope for the Rebellion."***

# %% [markdown]
# ## 3. Parse natural language questions
#
# In order to understand questions posed in natural language, we'll use another Watson service called [Conversation](https://www.ibm.com/watson/developercloud/doc/conversation/index.html). It can be used to design conversational agents or _chatbots_ that exhibit complex behavior, but for the purpose of this project, we'll only use it to parse certain kinds of queries.
#
# ### Create a Conversation service instance
#
# Just like you did for the Discovery service, create an instance of the Conversation service. Then launch the associated tool from the service dashboard.
#
# <img src="images/conversation-tooling.png" alt="Conversation service - Tool homepage" width="800" />
#
# A _workspace_ allows you to keep all the items you need for a particular application in one place, just like an _environment_ in case of the Discovery service. Create one called "Bookworm" with a suitable description, such as "I know a lot of stories. Ask me a question!"
#
# <img src="images/conversation-workspace.png" alt="Conversation service - Blank workspace" width="800" />
#
# This should open up a blank workspace, where you can add intents, define the entities you want the agent to idenitfy and structure the overall dialog.
#
# ### Add intents
#
# An _intent_ is the goal or purpose of a user's input. Create a set of intents (at least 3) that capture the different kinds of questions that you want the system to answer, e.g. _who_, _what_ and _where_. Along with each intent, add a list of user examples or _utterances_ that map to that intent.
#
# For instance, you could enter the following examples for the _where_ intent:
#
# - Where is the Jedi temple located?
# - Where was Luke born?
#
# The Conversation service recommends at least 5 examples for each intent so that Watson learns how to recognize it. These don't have to be very precise, but more examples the better.
#
# <img src="images/conversation-intents.png" alt="Conversation service - Intents listed" width="800" />
#
# Feel free to create your own intents, based on the kinds of questions you want the system to answer, e.g. "How many ...", "What are the most common ..." etc. Each intent will need to be mapped to an appropriate query.
#
# > See [**Defining intents**](https://www.ibm.com/watson/developercloud/doc/conversation/intents.html) for a helpful video and further instructions.
#
# **Q**: What intents did you add to the Conversation service instance?
#
# **A**:
# what, who and where
#
#
# **Q**: Pick one of these intents, and list at least 5 examples for the intent that you entered.
#
# **A**:
#
#  - what did Leila hide in R2-D2?
#  - what does Anakin begin to have vision of?
#  - who is Luke's Father?
#  - where do Luke and R2-D2 crash land?
#
# ### Add entities
#
# Once you have your intents set, let's tell the service what entities we want it to identify. One way to do this is using the tool interface, and entering them one-by-one.
#
# > Go to [**Defining entities**](https://www.ibm.com/watson/developercloud/doc/conversation/entities.html) to see how that is done.
#
# But that can be tedious! So let's refer back to the entities that the Discovery service identified, and load them in programmatically.
#
# As before, let's connect to the Conversation service first. Remember to enter your service credentials below.

# %%
# Connect to the Conversation service instance
# TODO: Enter your username and password from the Service Credentials tab in service-credentials.json
conversation_creds = helper.fetch_credentials('conversation')
conversation = watson_developer_cloud.ConversationV1(
    version='2017-02-03',
    username=conversation_creds['username'],
    password=conversation_creds['password'])

# %% [markdown]
# Fetch the workspace you just created called "Bookworm".

# %%
wrk, wrk_id = helper.fetch_object(conversation, "workspace", "Bookworm")
print(json.dumps(wrk, indent=2))
# Out:
# Found workspace: Bookworm (11ea3ebb-8bfc-4bcb-8214-bcffab229261)
# {
#   "status": "Training",
#   "updated": "2017-07-10T15:28:16.378Z",
#   "description": "I know a lot of stories. Ask me anything!",
#   "language": "en",
#   "created": "2017-07-10T15:09:06.419Z",
#   "workspace_id": "11ea3ebb-8bfc-4bcb-8214-bcffab229261",
#   "name": "Bookworm",
#   "metadata": null
# }

# %% [markdown]
# Collect all the entities from the Discovery service collection.

# %%
# Get all the entities from the collection and group them by type
response = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "return": "enriched_text.entities.type,enriched_text.entities.text"
    })

# Group individual entities by type ("Person", "Location", etc.)
entities_by_type = {}
for document in response["results"]:
    for entity in document["enriched_text"]["entities"]:
        if entity["type"] not in entities_by_type:
            entities_by_type[entity["type"]] = set()
        entities_by_type[entity["type"]].add(entity["text"])

# Ignore case to avoid duplicates
for entity_type in entities_by_type:
    entities_by_type[entity_type] = {
        e.lower(): e for e in entities_by_type[entity_type]
    }.values()

# Restructure for loading into Conversation workspace
entities_grouped = [{
    "entity": entity_type,
    "values": [{"value": entity} for entity in entities]}
        for entity_type, entities in entities_by_type.items()]
entities_grouped
# Out:
# [{'entity': u'City',
#   'values': [{'value': u'Gungans'},
#    {'value': u'Valorum'},
#    {'value': u'Theed'},
#    {'value': u'Kashyyyk'},
#    {'value': u'Coruscant'},
#    {'value': u'Mustafar'},
#    {'value': u'Padm\xe9'},
#    {'value': u'Podrace'},
#    {'value': u'Alderaan'},
#    {'value': u'Gungan'},
#    {'value': u'Tusken'},
#    {'value': u'Geonosis'}]},
#  {'entity': u'FieldTerminology', 'values': [{'value': u'the queen'}]},
#  {'entity': u'JobTitle',
#   'values': [{'value': u'Chancellor'},
#    {'value': u'representative'},
#    {'value': u'engineer'}]},
#  {'entity': u'Company',
#   'values': [{'value': u'Mos Espa'},
#    {'value': u'Federation Viceroy Nute Gunray'}]},
#  {'entity': u'Facility', 'values': [{'value': u'Jedi Temple'}]},
#  {'entity': u'Person',
#   'values': [{'value': u'Senator Padm\xe9 Amidala'},
#    {'value': u'Chancellor Valorum'},
#    {'value': u'Owen'},
#    {'value': u'Zam Wesell'},
#    {'value': u'Palpatine'},
#    {'value': u'Queen Amidala'},
#    {'value': u'Shmi'},
#    {'value': u'Darth Maul'},
#    {'value': u'Obi-Wan Kenobi'},
#    {'value': u'Yoda'},
#    {'value': u'Darth Vader'},
#    {'value': u'Qui-Gon'},
#    {'value': u'Anakin'},
#    {'value': u'Mustafar'},
#    {'value': u'Viceroy Nute Gunray'},
#    {'value': u'Boss Nass'},
#    {'value': u'Leia'},
#    {'value': u'Darth Sidious'},
#    {'value': u'Luke'},
#    {'value': u'Boba'},
#    {'value': u'Cliegg Lars'},
#    {'value': u'Beru Lars'},
#    {'value': u'Supreme Chancellor Palpatine'},
#    {'value': u'Organa'},
#    {'value': u'Anakin Skywalker'},
#    {'value': u'Obi-Wan'},
#    {'value': u'Senator Palpatine'},
#    {'value': u'Gunray'},
#    {'value': u'Jango Fett'},
#    {'value': u'Vader'},
#    {'value': u'Count Dooku'},
#    {'value': u'Mace Windu'},
#    {'value': u'Padm\xe9'},
#    {'value': u'Geonosis'},
#    {'value': u'Polis Massa'},
#    {'value': u'Amidala'},
#    {'value': u'Watto'}]},
#  {'entity': u'Country', 'values': [{'value': u'Naboo'}]},
#  {'entity': u'Organization',
#   'values': [{'value': u'droid army'},
#    {'value': u'Force'},
#    {'value': u'Federation'},
#    {'value': u'Senate'},
#    {'value': u'Jedi Council'},
#    {'value': u'Galactic Senate'},
#    {'value': u'Tusken Raiders'},
#    {'value': u'Trade Federation'}]},
#  {'entity': u'Quantity',
#   'values': [{'value': u'nine-year'},
#    {'value': u'Ten years'},
#    {'value': u'one'}]}]

# %% [markdown]
# Update the workspace with these entities and verify that have been added correctly.

# %%
# Add these grouped entities to the Conversation workspace
conversation.update_workspace(workspace_id=wrk_id, entities=entities_grouped)

workspace_details = conversation.get_workspace(workspace_id=wrk_id, export=True)
print(json.dumps(workspace_details["entities"], indent=2))
# Out:
# [
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "Company",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Mos Espa",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Federation Viceroy Nute Gunray",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   },
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "FieldTerminology",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "the queen",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   },
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "Facility",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Jedi Temple",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   },
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "Quantity",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "nine-year",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Ten years",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "one",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   },
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "Country",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Naboo",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   },
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "City",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Gungans",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Valorum",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Theed",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Kashyyyk",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Coruscant",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Mustafar",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Padm\u00e9",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Podrace",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Alderaan",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Gungan",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Tusken",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Geonosis",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   },
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "Organization",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "droid army",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Force",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Federation",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Senate",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Jedi Council",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Galactic Senate",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Tusken Raiders",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Trade Federation",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   },
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "Person",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Senator Padm\u00e9 Amidala",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Chancellor Valorum",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Owen",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Zam Wesell",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Palpatine",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Queen Amidala",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Shmi",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Darth Maul",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Obi-Wan Kenobi",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Yoda",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Darth Vader",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Qui-Gon",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Anakin",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Mustafar",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Viceroy Nute Gunray",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Boss Nass",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Leia",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Darth Sidious",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Luke",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Boba",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Cliegg Lars",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Beru Lars",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Supreme Chancellor Palpatine",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Organa",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Anakin Skywalker",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Obi-Wan",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Senator Palpatine",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Gunray",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Jango Fett",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Vader",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Count Dooku",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Mace Windu",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Padm\u00e9",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Geonosis",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Polis Massa",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Amidala",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Watto",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   },
#   {
#     "updated": "2017-07-10T15:28:55.358Z",
#     "description": null,
#     "created": "2017-07-10T15:28:55.358Z",
#     "entity": "JobTitle",
#     "source": null,
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "Chancellor",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "representative",
#         "created": "2017-07-10T15:28:55.358Z"
#       },
#       {
#         "updated": "2017-07-10T15:28:55.358Z",
#         "metadata": null,
#         "synonyms": [],
#         "value": "engineer",
#         "created": "2017-07-10T15:28:55.358Z"
#       }
#     ],
#     "type": null
#   }
# ]

# %% [markdown]
# _**Note**: Ensure that at least 3 entity types, with at least 1 example entity each have been added._
#
# Here is what the list of entities should look like through the Conversation tool.
#
# <img src="images/conversation-entities.png" alt="Conversation service - Entities listed" width="800" />
#
# **Q**: Name 3 entity types that were added, with at least 1 example entity each (e.g. entity type: _City_, example: _Los Angeles_).
#
# **A**:
#  - entity type: _City_, example: _Theed_
#  - entity type: _Country_, example: _Naboo_
#  - entity type: _Facility_, example: _Jedi Temple_

# %% [markdown]
# ### Design dialog flow
#
# As a final step in creating the Conversation interface, let's design a typical dialog with a user. The most intuitive way to do this is to use the Dialog tab in the tool. Here, you can add _nodes_ that capture different stages in the dialog flow, and connect them in a meaningful way.
#
# Go ahead and add at least 3 dialog nodes. Specify the triggers in terms of the intents and entities that you'd like to match, and an optional intermediate response like "Let me find that out for you." The actual response will be fetched by querying the Discovery service.
#
# Here is what the dialog nodes should look like.
#
# <img src="images/conversation-dialog_nodes.png" alt="Conversation service - Dialog nodes" width="640" />
#
# **Q**: Specify 3 dialog nodes you added, along with the trigger (intent and/or entities) for each.
#
# **A**:
#   - Person: #who
#   - Location: #where
#   - Object: #what

# %% [markdown]
# ### Test dialog
#
# Let's run through a test dialog to demonstrate how the system transitions to one of the nodes you defined above.

# %%
# Testing the dialog flow

# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "Who is Luke's father?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "entities": [
#     {
#       "confidence": 1,
#       "location": [
#         7,
#         11
#       ],
#       "value": "Luke",
#       "entity": "Person"
#     }
#   ],
#   "intents": [
#     {
#       "confidence": 1,
#       "intent": "who"
#     }
#   ],
#   "output": {
#     "text": [
#       "Let me find it for you"
#     ],
#     "log_messages": [],
#     "nodes_visited": [
#       "Person"
#     ]
#   },
#   "context": {
#     "conversation_id": "3b13858e-ce33-4f83-bb6c-b9a6a2ece9cb",
#     "system": {
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_request_counter": 1,
#       "dialog_turn_counter": 1,
#       "branch_exited": true,
#       "_node_output_map": {
#         "node_2_1499699879929": [
#           0
#         ]
#       },
#       "branch_exited_reason": "completed"
#     }
#   },
#   "input": {
#     "text": "Who is Luke's father?",
#     "context": {
#       "conversation_id": "1d868bcb-e70e-4788-bfd6-a4392dd35285",
#       "system": {
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ],
#         "dialog_request_counter": 1,
#         "dialog_turn_counter": 1,
#         "branch_exited": true,
#         "_node_output_map": {
#           "Welcome": [
#             0
#           ]
#         },
#         "branch_exited_reason": "completed"
#       }
#     }
#   }
# }

# %% [markdown]
# ## 4. Query document collection to fetch answers
#
# The Discovery service includes a simple mechanism to make queries against your enriched collection of documents. But you have a lot of control over what fields are searched, how results are aggregated and values are returned.
#
# ### Process sample question
#
# Choose a sample nautal language question to ask, and run it through the Conversation service, just like you did above when testing dialog flow.

# %%
# TODO: Run a sample question through Conversation service
# TODO: Run a sample question through Conversation service

# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "where do Luke and R2-D2 crash land?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "entities": [
#     {
#       "confidence": 1,
#       "location": [
#         9,
#         13
#       ],
#       "value": "Luke",
#       "entity": "Person"
#     }
#   ],
#   "intents": [
#     {
#       "confidence": 1,
#       "intent": "where"
#     }
#   ],
#   "output": {
#     "text": [
#       "Finding the location"
#     ],
#     "log_messages": [],
#     "nodes_visited": [
#       "Location"
#     ]
#   },
#   "context": {
#     "conversation_id": "586a91b9-e2f2-4532-ab7a-4846bb498e01",
#     "system": {
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_request_counter": 1,
#       "dialog_turn_counter": 1,
#       "branch_exited": true,
#       "_node_output_map": {
#         "node_4_1499700005271": [
#           0
#         ]
#       },
#       "branch_exited_reason": "completed"
#     }
#   },
#   "input": {
#     "text": "where do Luke and R2-D2 crash land?",
#     "context": {
#       "conversation_id": "95ed49d3-8a60-4ba2-b4e1-8fcc98cf0741",
#       "system": {
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ],
#         "dialog_request_counter": 1,
#         "dialog_turn_counter": 1,
#         "branch_exited": true,
#         "_node_output_map": {
#           "Welcome": [
#             0
#           ]
#         },
#         "branch_exited_reason": "completed"
#       }
#     }
#   }
# }

# %% [markdown]
# Now extract the intent and entities identified in the question, and optionally what dialog node was triggered (in case you need it later to customize your response). Some sample code is provided below, but you may need to modify it.

# %%
# TODO: Identify the intent(s) the user expressed (typically a single one)
query_intents = [intent["intent"] for intent in results["intents"]]
print("Intent(s):", query_intents)

# TODO: Extract the entities found in the question text
query_entities = [entity["value"] for entity in results["entities"]]
print("Entities:", query_entities)

# TODO: (optional) Find out what dialog node was triggered
# Out:
# ('Intent(s):', [u'where'])
# ('Entities:', [u'Luke'])

# %% [markdown]
# ### Query the collection
#
# Design a query based on the information extracted above, and run it against the document collection. The sample query provided below simple looks for all the entities in the raw `text` field. Modify it to suit your needs.
#
# Take a look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python#query-collection) to learn more about the query options available, and for more guidance see this [documentation page](https://www.ibm.com/watson/developercloud/doc/discovery/using.html).
#
# _**Note**: You may want to design different queries based on the intent / dialog node that was triggered._

# %%
# TODO: Query the Discovery service based on the intent and entities
query_results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "text:{}".format(",".join("\"{}\"".format(e) for e in query_entities)),
        "return": "text"
    })
print(json.dumps(query_results, indent=2))
# Out:
# {
#   "matching_results": 20,
#   "results": [
#     {
#       "text": "The galaxy is in the midst of a civil war. Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet. Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader. Before she is captured, Leia hides the plans in the memory of an astromech droid, R2-D2, along with a holographic recording. R2-D2 flees to the surface of the desert planet Tatooine with C-3PO, a protocol droid.",
#       "score": 1.2455122,
#       "id": "01d36fb9-08ae-4912-aa3b-98afa552de52"
#     },
#     {
#       "text": "Luke Skywalker initiates a plan to rescue Han Solo from the crime lord Jabba the Hutt with the help of Princess Leia, Lando Calrissian, Chewbacca, C-3PO, and R2-D2. Leia infiltrates Jabba's palace on Tatooine disguised as a bounty hunter with Chewbacca as her prisoner. Lando is already there disguised as a guard. Leia releases Han from his carbonite prison, but she is captured and enslaved. Luke arrives soon afterward but after a tense standoff, he is captured. After Luke survives his battle with Jabba's Rancor, Jabba sentences him and Han to death by feeding them to the Sarlacc. Luke frees himself and battles Jabba's guards. During the chaos, Boba Fett, who has remained at Jabba's palace since delivering Han, attempts to attack Luke, but Han inadvertently knocks him into the Sarlacc pit. Meanwhile, Leia strangles Jabba to death, and Luke destroys Jabba's sail barge as the group escapes. While the others rendezvous with the Rebel Alliance, Luke returns to Dagobah where he finds that Yoda is dying. Before he dies, Yoda confirms that Darth Vader, once known as Anakin Skywalker, is Luke's father, and there is \"another Skywalker\". The spirit of Obi-Wan Kenobi confirms that this other Skywalker is Luke's twin sister, Leia. Obi-Wan tells Luke that he must fight Vader again to defeat the Empire.",
#       "score": 1.23083,
#       "id": "c027df99-79f3-455f-a07f-25b30a77f251"
#     },
#     {
#       "text": "Three decades after the destruction of the second Death Star, the First Order has risen from the fallen Galactic Empire and seeks to eliminate the New Republic. The Resistance, backed by the Republic and led by General Leia Organa, opposes them while searching for her brother, Luke Skywalker, to enlist his aid.",
#       "score": 1.1008878,
#       "id": "028632dd-7f82-4e39-a1c0-43d407e0015a"
#     },
#     {
#       "text": "The Rebel fleet prepares to jump to hyperspace but are intercepted by Vader's flagship. Vader invades the command ship and kills many rebels in his pursuit of the schematics, but a small starship escapes with them on board. Aboard the fleeing ship, Princess Leia declares that the schematics will provide hope for the Rebellion.",
#       "score": 1.1008878,
#       "id": "70a24bdc-5966-4acb-b487-6c57d5750191"
#     },
#     {
#       "text": "On the asteroid Polis Massa, Obi-Wan regroups with Yoda and Padm\u00e9 gives birth to twins Luke and Leia before dying. A funeral is held for Padm\u00e9 on Naboo. On Mustafar, Palpatine finds a severely burnt Vader still alive. After returning to Coruscant, Vader's mutilated body is amputated and covered in a black armored suit. Palpatine explains to Vader that he killed Padm\u00e9 in his anger. Meanwhile, Obi-Wan and Yoda decide to conceal the twins from the Sith, as they are the galaxy's only hope for freedom. Yoda exiles himself to the planet Dagobah, while Vader and the Emperor oversee the construction of a superstation, the Death Star. Bail Organa adopts Leia as his own daughter and takes her to Alderaan, while Obi-Wan delivers Luke to his step-family Owen and Beru Lars on Tatooine, where Obi-Wan intends to watch over Luke until the time is right to challenge the Empire.",
#       "score": 0.9341342,
#       "id": "9c57b56e-c0d8-41b1-8343-168c50732611"
#     },
#     {
#       "text": "On patrol, Han and Chewbacca discover the meteor Luke had planned to investigate is actually a probe droid, which alerts the Empire to the Rebels\u2019 location. The Empire launches a large-scale attack, using AT-AT Walkers to capture the base. Despite heavy resistance, the Walkers destroy the base's shield generator and force the Rebels to retreat. Han and Leia escape on the Millennium Falcon with C-3PO and Chewbacca, but their hyperdrive malfunctions. They hide in an asteroid field, where Han and Leia grow closer, and eventually, kiss. Vader summons bounty hunters, including the notorious Boba Fett, to assist in finding the Falcon. Luke, meanwhile, escapes with R2-D2 in his X-wing fighter and crash-lands on the swamp planet Dagobah. He meets a diminutive creature who is revealed to be Yoda; after conferring with Obi-Wan's spirit, Yoda reluctantly accepts Luke as his student. Yoda trains Luke as a Jedi and raises his sunken ship from the swamp with the power of the Force.",
#       "score": 0.9341342,
#       "id": "38f36f4a-2751-45e9-bb5d-cc6bbe1655d8"
#     },
#     {
#       "text": "Vader goes back on his agreement with Lando to let Leia and Chewbacca stay in Cloud City and instead, takes them into custody. He intends to hold Luke in suspended animation in a block of carbonite for delivery to the Emperor. To test this process, he selects Han to be frozen against the protests of Fett, who fears he will lose his bounty. Vader hands the frozen Han over to Fett, who intends to leave for Tatooine to deliver Han to Jabba the Hutt and claim the bounty on Solo. Lando, who was forced into cooperating with the Empire, initiates an escape and frees Leia and the others. They then try to save Han but are too late and unable to stop Fett as he departs on his ship. They fight their way back to the Falcon and flee Cloud City.",
#       "score": 0.9341342,
#       "id": "d655a72d-f40b-4957-96ec-e432afa57826"
#     },
#     {
#       "text": "The Rebel Alliance learns that the Empire has been constructing a new Death Star under the supervision of Emperor Palpatine himself. As the station is protected by an energy shield, Han leads a strike team to destroy the shield generator on the forest moon of Endor; doing so would allow a squadron of starfighters to destroy the Death Star. The strike team, accompanied by Luke and Leia, travels to Endor in a stolen Imperial shuttle. On Endor, Luke and his companions encounter a tribe of Ewoks and, after an initial conflict, gain their trust. Later, Luke tells Leia that she is his sister, Vader is their father, and that he must go and confront him. Surrendering to Imperial troops, Luke is brought to Vader and unsuccessfully tries to convince him to turn from the dark side of the Force.",
#       "score": 0.9341342,
#       "id": "43483815-1ded-4ce1-9dd9-bc165d47019c"
#     },
#     {
#       "text": "Three years after the destruction of the Death Star, the Rebel Alliance has been driven from their former base on Yavin IV by the Galactic Empire. The Rebels, led by Princess Leia, have set up their new base on the ice planet Hoth. The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels\u2019 new base by dispatching probe droids across the galaxy.",
#       "score": 0.8807102,
#       "id": "3725409d-4d53-4591-86f6-66d697df293e"
#     },
#     {
#       "text": "Later, aboard a medical frigate in the Rebel fleet, Luke's severed hand is replaced with a robotic prosthetic. Lando and Chewbacca set off for Tatooine in the Falcon in order to find Jabba the Hutt and Boba Fett to save Han. As the Falcon departs, Luke, Leia, R2-D2, and C-3PO gaze out on the galaxy and await word from Lando.",
#       "score": 0.8807102,
#       "id": "b3726462-7273-4c9e-8ff1-d145daaf76da"
#     }
#   ]
# }

# %%
# TODO: Query the Discovery service based on the intent and entities
query_results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "natural_language_query": question,
        "return": "enriched_text.relations"
    })
print(json.dumps(query_results, indent=2))
# Out:
# {
#   "matching_results": 39,
#   "results": [
#     {
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "text": "discover",
#               "verb": {
#                 "text": "discover",
#                 "tense": "present"
#               },
#               "lemmatized": "discover"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Chewbacca"
#                 },
#                 {
#                   "text": "Han"
#                 },
#                 {
#                   "text": "patrol"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Han",
#                   "type": "Person"
#                 }
#               ],
#               "text": "patrol, Han and Chewbacca"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "probe droid"
#                 },
#                 {
#                   "text": "meteor Luke"
#                 },
#                 {
#                   "text": "Rebels"
#                 },
#                 {
#                   "text": "Empire"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Rebels",
#                   "disambiguated": {
#                     "yago": "http://yago-knowledge.org/resource/Rebel_Alliance",
#                     "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#                     "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#                     "name": "Rebel Alliance"
#                   },
#                   "type": "Organization"
#                 }
#               ],
#               "text": "the meteor Luke had planned to investigate is actually a probe droid, which alerts the Empire to the Rebels\u2019 location"
#             },
#             "sentence": "On patrol, Han and Chewbacca discover the meteor Luke had planned to investigate is actually a probe droid, which alerts the Empire to the Rebels\u2019 location."
#           },
#           {
#             "action": {
#               "text": "planned",
#               "verb": {
#                 "text": "plan",
#                 "tense": "past"
#               },
#               "lemmatized": "plan"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "meteor Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "the meteor Luke"
#             },
#             "object": {
#               "text": "to investigate",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.300967,
#                 "type": "negative"
#               }
#             },
#             "sentence": "On patrol, Han and Chewbacca discover the meteor Luke had planned to investigate is actually a probe droid, which alerts the Empire to the Rebels\u2019 location."
#           },
#           {
#             "action": {
#               "text": "is",
#               "verb": {
#                 "text": "be",
#                 "tense": "past"
#               },
#               "lemmatized": "be"
#             },
#             "sentence": "On patrol, Han and Chewbacca discover the meteor Luke had planned to investigate is actually a probe droid, which alerts the Empire to the Rebels\u2019 location.",
#             "object": {
#               "keywords": [
#                 {
#                   "text": "probe droid"
#                 }
#               ],
#               "text": "a probe droid",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.551922,
#                 "type": "positive"
#               }
#             },
#             "location": {
#               "text": "On patrol"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "meteor Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "the meteor Luke"
#             }
#           },
#           {
#             "action": {
#               "text": "alerts",
#               "verb": {
#                 "text": "alert",
#                 "tense": "present"
#               },
#               "lemmatized": "alert"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "probe droid"
#                 }
#               ],
#               "text": "a probe droid",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.551922,
#                 "type": "positive"
#               }
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Empire"
#                 }
#               ],
#               "text": "the Empire",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.574735,
#                 "type": "positive"
#               }
#             },
#             "sentence": "On patrol, Han and Chewbacca discover the meteor Luke had planned to investigate is actually a probe droid, which alerts the Empire to the Rebels\u2019 location."
#           },
#           {
#             "action": {
#               "text": "launches",
#               "verb": {
#                 "text": "launch",
#                 "tense": "present"
#               },
#               "lemmatized": "launch"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Empire"
#                 }
#               ],
#               "text": "The Empire",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.574735,
#                 "type": "positive"
#               }
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "large-scale attack"
#                 }
#               ],
#               "text": "a large-scale attack"
#             },
#             "sentence": " The Empire launches a large-scale attack, using AT-AT Walkers to capture the base."
#           },
#           {
#             "action": {
#               "text": "using",
#               "verb": {
#                 "text": "use",
#                 "tense": "present"
#               },
#               "lemmatized": "use"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Empire"
#                 }
#               ],
#               "text": "The Empire",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.574735,
#                 "type": "positive"
#               }
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "AT-AT Walkers"
#                 }
#               ],
#               "text": "AT-AT Walkers",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.448255,
#                 "type": "positive"
#               }
#             },
#             "sentence": " The Empire launches a large-scale attack, using AT-AT Walkers to capture the base."
#           },
#           {
#             "action": {
#               "text": "to capture",
#               "verb": {
#                 "text": "capture",
#                 "tense": "future"
#               },
#               "lemmatized": "to capture"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "AT-AT Walkers"
#                 }
#               ],
#               "text": "AT-AT Walkers",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.448255,
#                 "type": "positive"
#               }
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "base"
#                 }
#               ],
#               "text": "the base",
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.489129,
#                 "type": "positive"
#               }
#             },
#             "sentence": " The Empire launches a large-scale attack, using AT-AT Walkers to capture the base."
#           },
#           {
#             "action": {
#               "text": "destroy",
#               "verb": {
#                 "text": "destroy",
#                 "tense": "present"
#               },
#               "lemmatized": "destroy"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Walkers"
#                 }
#               ],
#               "text": "the Walkers"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "shield generator"
#                 },
#                 {
#                   "text": "base"
#                 }
#               ],
#               "text": "the base's shield generator",
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.726342,
#                 "type": "negative"
#               }
#             },
#             "sentence": " Despite heavy resistance, the Walkers destroy the base's shield generator and force the Rebels to retreat."
#           },
#           {
#             "action": {
#               "text": "force",
#               "verb": {
#                 "text": "force",
#                 "tense": "present"
#               },
#               "lemmatized": "force"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Walkers"
#                 }
#               ],
#               "text": "the Walkers"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Rebels"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Rebels",
#                   "disambiguated": {
#                     "yago": "http://yago-knowledge.org/resource/Rebel_Alliance",
#                     "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#                     "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#                     "name": "Rebel Alliance"
#                   },
#                   "type": "Organization"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.659625,
#                 "type": "positive"
#               },
#               "text": "the Rebels"
#             },
#             "sentence": " Despite heavy resistance, the Walkers destroy the base's shield generator and force the Rebels to retreat."
#           },
#           {
#             "action": {
#               "text": "to retreat",
#               "verb": {
#                 "text": "retreat",
#                 "tense": "future"
#               },
#               "lemmatized": "to retreat"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Rebels"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Rebels",
#                   "disambiguated": {
#                     "yago": "http://yago-knowledge.org/resource/Rebel_Alliance",
#                     "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#                     "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#                     "name": "Rebel Alliance"
#                   },
#                   "type": "Organization"
#                 }
#               ],
#               "text": "the Rebels"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "shield generator"
#                 },
#                 {
#                   "text": "Walkers"
#                 },
#                 {
#                   "text": "base"
#                 },
#                 {
#                   "text": "force"
#                 }
#               ],
#               "text": "the Walkers destroy the base's shield generator and force",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.306289,
#                 "type": "negative"
#               }
#             },
#             "sentence": " Despite heavy resistance, the Walkers destroy the base's shield generator and force the Rebels to retreat."
#           },
#           {
#             "action": {
#               "text": "hide",
#               "verb": {
#                 "text": "hide",
#                 "tense": "present"
#               },
#               "lemmatized": "hide"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Rebels",
#                   "disambiguated": {
#                     "yago": "http://yago-knowledge.org/resource/Rebel_Alliance",
#                     "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#                     "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#                     "name": "Rebel Alliance"
#                   },
#                   "type": "Organization"
#                 }
#               ],
#               "text": "They"
#             },
#             "location": {
#               "entities": [
#                 {
#                   "text": "Han",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Leia",
#                   "type": "Person"
#                 }
#               ],
#               "text": "in an asteroid field, where Han and Leia grow closer, and eventually, kiss"
#             },
#             "sentence": " They hide in an asteroid field, where Han and Leia grow closer, and eventually, kiss."
#           },
#           {
#             "action": {
#               "text": "grow",
#               "verb": {
#                 "text": "grow",
#                 "tense": "present"
#               },
#               "lemmatized": "grow"
#             },
#             "sentence": " They hide in an asteroid field, where Han and Leia grow closer, and eventually, kiss.",
#             "object": {
#               "text": "closer"
#             },
#             "location": {
#               "text": "an asteroid field"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Leia"
#                 },
#                 {
#                   "text": "Han"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Han",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Leia",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Han and Leia"
#             }
#           },
#           {
#             "action": {
#               "text": "including",
#               "verb": {
#                 "text": "include",
#                 "tense": "present"
#               },
#               "lemmatized": "include"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "notorious Boba Fett"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Boba Fett",
#                   "type": "Person"
#                 }
#               ],
#               "text": "the notorious Boba Fett"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "bounty hunters"
#                 }
#               ],
#               "text": "bounty hunters",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.662881,
#                 "type": "positive"
#               }
#             },
#             "sentence": " Vader summons bounty hunters, including the notorious Boba Fett, to assist in finding the Falcon."
#           },
#           {
#             "action": {
#               "text": "meets",
#               "verb": {
#                 "text": "meet",
#                 "tense": "present"
#               },
#               "lemmatized": "meet"
#             },
#             "subject": {
#               "text": "He"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "diminutive creature"
#                 },
#                 {
#                   "text": "Yoda"
#                 }
#               ],
#               "text": "a diminutive creature who is revealed to be Yoda",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.68227,
#                 "type": "negative"
#               }
#             },
#             "sentence": " He meets a diminutive creature who is revealed to be Yoda; after conferring with Obi-Wan's spirit, Yoda reluctantly accepts Luke as his student."
#           },
#           {
#             "action": {
#               "text": "conferring",
#               "verb": {
#                 "text": "confer",
#                 "tense": "present"
#               },
#               "lemmatized": "confer"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "diminutive creature"
#                 }
#               ],
#               "text": "a diminutive creature"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Obi-Wan"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Obi-Wan",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.650867,
#                 "type": "positive"
#               },
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.679698,
#                 "type": "positive"
#               },
#               "text": "with Obi-Wan's spirit"
#             },
#             "sentence": " He meets a diminutive creature who is revealed to be Yoda; after conferring with Obi-Wan's spirit, Yoda reluctantly accepts Luke as his student."
#           },
#           {
#             "action": {
#               "text": "accepts",
#               "verb": {
#                 "text": "accept",
#                 "tense": "present"
#               },
#               "lemmatized": "accept"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Yoda"
#                 }
#               ],
#               "text": "Yoda"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "sentence": " He meets a diminutive creature who is revealed to be Yoda; after conferring with Obi-Wan's spirit, Yoda reluctantly accepts Luke as his student."
#           }
#         ]
#       },
#       "score": 0.65051275,
#       "id": "38f36f4a-2751-45e9-bb5d-cc6bbe1655d8"
#     },
#     {
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "text": "falls",
#               "verb": {
#                 "text": "fall",
#                 "tense": "present"
#               },
#               "lemmatized": "fall"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.79692,
#                 "type": "negative"
#               },
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.543747,
#                 "type": "negative"
#               },
#               "text": "into Vader's trap"
#             },
#             "sentence": "After arriving at Cloud City, and engaging in a brief confrontation with Boba Fett, Luke ultimately falls into Vader's trap."
#           },
#           {
#             "action": {
#               "text": "severs",
#               "verb": {
#                 "text": "sever",
#                 "tense": "present"
#               },
#               "lemmatized": "sever"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Vader"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 },
#                 {
#                   "text": "hand"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.740087,
#                 "type": "positive"
#               },
#               "text": "Luke's right hand"
#             },
#             "sentence": " The two engage in a lightsaber duel that leads them over the city's central air shaft where, as his mentors warned, Luke proves to be no match for Vader who severs Luke's right hand, causing him to lose his weapon."
#           },
#           {
#             "action": {
#               "text": "to lose",
#               "verb": {
#                 "text": "lose",
#                 "tense": "future"
#               },
#               "lemmatized": "to lose"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "him"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "weapon"
#                 }
#               ],
#               "text": "his weapon",
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.803394,
#                 "type": "negative"
#               }
#             },
#             "sentence": " The two engage in a lightsaber duel that leads them over the city's central air shaft where, as his mentors warned, Luke proves to be no match for Vader who severs Luke's right hand, causing him to lose his weapon."
#           },
#           {
#             "action": {
#               "text": "refuses",
#               "verb": {
#                 "text": "refuse",
#                 "tense": "present"
#               },
#               "lemmatized": "refuse"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 },
#                 {
#                   "text": "Emperor"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.353076,
#                 "type": "negative"
#               },
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.654624,
#                 "type": "negative"
#               },
#               "text": "to join Vader against the Emperor"
#             },
#             "sentence": " After Luke refuses to join Vader against the Emperor, Vader reveals that he is Luke's father, Anakin Skywalker."
#           },
#           {
#             "action": {
#               "text": "refuses to join",
#               "verb": {
#                 "text": "join",
#                 "tense": "future"
#               },
#               "lemmatized": "refuse to join"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Vader"
#             },
#             "sentence": " After Luke refuses to join Vader against the Emperor, Vader reveals that he is Luke's father, Anakin Skywalker."
#           },
#           {
#             "action": {
#               "text": "reveals",
#               "verb": {
#                 "text": "reveal",
#                 "tense": "present"
#               },
#               "lemmatized": "reveal"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Vader"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Anakin Skywalker"
#                 },
#                 {
#                   "text": "Luke"
#                 },
#                 {
#                   "text": "father"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Anakin Skywalker",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.592674,
#                 "type": "positive"
#               },
#               "text": "that he is Luke's father, Anakin Skywalker"
#             },
#             "sentence": " After Luke refuses to join Vader against the Emperor, Vader reveals that he is Luke's father, Anakin Skywalker."
#           },
#           {
#             "action": {
#               "text": "Horrified",
#               "verb": {
#                 "text": "Horrified",
#                 "tense": "past"
#               },
#               "lemmatized": "Horrified"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "truth"
#                 }
#               ],
#               "text": "by the truth"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.635244,
#                 "type": "negative"
#               },
#               "text": "Luke"
#             },
#             "sentence": " Horrified by the truth, Luke throws himself off the bridge and is pulled into an air shaft."
#           },
#           {
#             "action": {
#               "text": "throws",
#               "verb": {
#                 "text": "throw",
#                 "tense": "present"
#               },
#               "lemmatized": "throw"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.298094,
#                 "type": "negative"
#               },
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "himself"
#             },
#             "sentence": " Horrified by the truth, Luke throws himself off the bridge and is pulled into an air shaft."
#           },
#           {
#             "action": {
#               "text": "is ejected",
#               "verb": {
#                 "text": "eject",
#                 "tense": "past"
#               },
#               "lemmatized": "be eject"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "He"
#             },
#             "location": {
#               "text": "beneath the floating city",
#               "sentiment": {
#                 "score": "0.762826",
#                 "type": "positive"
#               }
#             },
#             "sentence": " He is ejected beneath the floating city but is able to grab onto an antenna."
#           },
#           {
#             "action": {
#               "text": "to grab",
#               "verb": {
#                 "text": "grab",
#                 "tense": "future"
#               },
#               "lemmatized": "to grab"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "He"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "antenna"
#                 }
#               ],
#               "text": "onto an antenna"
#             },
#             "sentence": " He is ejected beneath the floating city but is able to grab onto an antenna."
#           },
#           {
#             "action": {
#               "text": "makes",
#               "verb": {
#                 "text": "make",
#                 "tense": "present"
#               },
#               "lemmatized": "make"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "He"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "desperate telepathic plea"
#                 }
#               ],
#               "text": "a desperate telepathic plea",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.720497,
#                 "type": "positive"
#               },
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.472217,
#                 "type": "positive"
#               }
#             },
#             "sentence": " He makes a desperate telepathic plea to Leia, who senses it and persuades Lando to return for him in the Falcon."
#           },
#           {
#             "action": {
#               "text": "senses",
#               "verb": {
#                 "text": "sense",
#                 "tense": "present"
#               },
#               "lemmatized": "sense"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Leia"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Leia",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Leia"
#             },
#             "object": {
#               "text": "it",
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.437227,
#                 "type": "positive"
#               }
#             },
#             "sentence": " He makes a desperate telepathic plea to Leia, who senses it and persuades Lando to return for him in the Falcon."
#           },
#           {
#             "action": {
#               "text": "persuades",
#               "verb": {
#                 "text": "persuade",
#                 "tense": "present"
#               },
#               "lemmatized": "persuade"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Lando"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Lando",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Lando"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Falcon"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Lando",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.404799,
#                 "type": "negative"
#               },
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.711892,
#                 "type": "positive"
#               },
#               "text": "to return for him in the Falcon"
#             },
#             "sentence": " He makes a desperate telepathic plea to Leia, who senses it and persuades Lando to return for him in the Falcon."
#           },
#           {
#             "action": {
#               "text": "is",
#               "verb": {
#                 "text": "be",
#                 "tense": "present"
#               },
#               "lemmatized": "be"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "board"
#                 }
#               ],
#               "text": "brought on board"
#             },
#             "sentence": " After Luke is brought on board, they are chased by TIE fighters but R2-D2 reactivates the Falcon's hyperdrive, allowing them to escape."
#           },
#           {
#             "action": {
#               "text": "are chased",
#               "verb": {
#                 "text": "be",
#                 "tense": "present"
#               },
#               "lemmatized": "be chase"
#             },
#             "subject": {
#               "text": "they"
#             },
#             "sentence": " After Luke is brought on board, they are chased by TIE fighters but R2-D2 reactivates the Falcon's hyperdrive, allowing them to escape."
#           },
#           {
#             "action": {
#               "text": "are chased",
#               "verb": {
#                 "text": "chase",
#                 "tense": "past"
#               },
#               "lemmatized": "be chase"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "TIE fighters"
#                 },
#                 {
#                   "text": "R2-D2"
#                 },
#                 {
#                   "text": "Falcon"
#                 },
#                 {
#                   "text": "hyperdrive"
#                 }
#               ],
#               "text": "by TIE fighters but R2-D2 reactivates the Falcon's hyperdrive"
#             },
#             "object": {
#               "text": "they",
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.310199,
#                 "type": "negative"
#               }
#             },
#             "sentence": " After Luke is brought on board, they are chased by TIE fighters but R2-D2 reactivates the Falcon's hyperdrive, allowing them to escape."
#           }
#         ]
#       },
#       "score": 0.53728706,
#       "id": "6d9d2aad-dae3-4aa6-a672-0427154cfcc0"
#     },
#     {
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "text": "initiates",
#               "verb": {
#                 "text": "initiate",
#                 "tense": "present"
#               },
#               "lemmatized": "initiate"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Luke Skywalker"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Anakin Skywalker",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke Skywalker"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "crime lord Jabba"
#                 },
#                 {
#                   "text": "Lando Calrissian"
#                 },
#                 {
#                   "text": "Princess Leia"
#                 },
#                 {
#                   "text": "Han Solo"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Han",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Princess Leia",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Lando Calrissian",
#                   "type": "Person"
#                 }
#               ],
#               "text": "a plan to rescue Han Solo from the crime lord Jabba the Hutt with the help of Princess Leia, Lando Calrissian, Chewbacca, C-3PO, and R2-D2"
#             },
#             "sentence": "Luke Skywalker initiates a plan to rescue Han Solo from the crime lord Jabba the Hutt with the help of Princess Leia, Lando Calrissian, Chewbacca, C-3PO, and R2-D2."
#           },
#           {
#             "action": {
#               "text": "to rescue",
#               "verb": {
#                 "text": "rescue",
#                 "tense": "future"
#               },
#               "lemmatized": "to rescue"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "crime"
#                 }
#               ],
#               "text": "from the crime"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Han Solo"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Han",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.731939,
#                 "type": "positive"
#               },
#               "text": "Han Solo"
#             },
#             "sentence": "Luke Skywalker initiates a plan to rescue Han Solo from the crime lord Jabba the Hutt with the help of Princess Leia, Lando Calrissian, Chewbacca, C-3PO, and R2-D2."
#           },
#           {
#             "action": {
#               "text": "infiltrates",
#               "verb": {
#                 "text": "infiltrate",
#                 "tense": "present"
#               },
#               "lemmatized": "infiltrate"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Leia"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Princess Leia",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Leia"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Jabba"
#                 },
#                 {
#                   "text": "Tatooine"
#                 },
#                 {
#                   "text": "palace"
#                 }
#               ],
#               "text": "Jabba's palace on Tatooine"
#             },
#             "sentence": " Leia infiltrates Jabba's palace on Tatooine disguised as a bounty hunter with Chewbacca as her prisoner."
#           },
#           {
#             "action": {
#               "text": "disguised",
#               "verb": {
#                 "text": "disguise",
#                 "tense": "past"
#               },
#               "lemmatized": "disguise"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Tatooine"
#                 }
#               ],
#               "text": "Tatooine"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "bounty hunter"
#                 },
#                 {
#                   "text": "Chewbacca"
#                 },
#                 {
#                   "text": "prisoner"
#                 }
#               ],
#               "text": "as a bounty hunter with Chewbacca as her prisoner",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.583012,
#                 "type": "positive"
#               },
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.545709,
#                 "type": "positive"
#               }
#             },
#             "sentence": " Leia infiltrates Jabba's palace on Tatooine disguised as a bounty hunter with Chewbacca as her prisoner."
#           },
#           {
#             "action": {
#               "text": "is",
#               "verb": {
#                 "text": "be",
#                 "tense": "present"
#               },
#               "lemmatized": "be"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Lando"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Lando Calrissian",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Lando"
#             },
#             "sentence": " Lando is already there disguised as a guard."
#           },
#           {
#             "action": {
#               "text": "arrives",
#               "verb": {
#                 "text": "arrive",
#                 "tense": "present"
#               },
#               "lemmatized": "arrive"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "sentence": " Luke arrives soon afterward but after a tense standoff, he is captured."
#           },
#           {
#             "action": {
#               "text": "is captured",
#               "verb": {
#                 "text": "capture",
#                 "tense": "past"
#               },
#               "lemmatized": "be capture"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "he"
#             },
#             "sentence": " Luke arrives soon afterward but after a tense standoff, he is captured."
#           },
#           {
#             "action": {
#               "text": "survives",
#               "verb": {
#                 "text": "survive",
#                 "tense": "present"
#               },
#               "lemmatized": "survive"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Luke"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "battle"
#                 }
#               ],
#               "text": "his battle",
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.475193,
#                 "type": "negative"
#               }
#             },
#             "sentence": " After Luke survives his battle with Jabba's Rancor, Jabba sentences him and Han to death by feeding them to the Sarlacc."
#           },
#           {
#             "action": {
#               "text": "sentences",
#               "verb": {
#                 "text": "sentence",
#                 "tense": "present"
#               },
#               "lemmatized": "sentence"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Jabba"
#                 }
#               ],
#               "text": "Jabba"
#             },
#             "object": {
#               "text": "him",
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.428959,
#                 "type": "negative"
#               }
#             },
#             "sentence": " After Luke survives his battle with Jabba's Rancor, Jabba sentences him and Han to death by feeding them to the Sarlacc."
#           },
#           {
#             "action": {
#               "text": "feeding",
#               "verb": {
#                 "text": "feed",
#                 "tense": "present"
#               },
#               "lemmatized": "feed"
#             },
#             "subject": {
#               "text": "them"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Sarlacc"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Sarlacc",
#                   "type": "City"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.56893,
#                 "type": "positive"
#               },
#               "text": "to the Sarlacc"
#             },
#             "sentence": " After Luke survives his battle with Jabba's Rancor, Jabba sentences him and Han to death by feeding them to the Sarlacc."
#           },
#           {
#             "action": {
#               "text": "frees",
#               "verb": {
#                 "text": "free",
#                 "tense": "present"
#               },
#               "lemmatized": "free"
#             },
#             "subject": {
#               "keywords": [
# ...
#               "keywords": [
#                 {
#                   "text": "statements"
#                 }
#               ],
#               "text": "statements"
#             },
#             "sentence": " Contrary to his uncle's statements, Luke learns that his father, Anakin, fought alongside Obi-Wan as a Jedi Knight."
#           },
#           {
#             "action": {
#               "text": "was",
#               "verb": {
#                 "text": "be",
#                 "tense": "past"
#               },
#               "lemmatized": "be"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Vader"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Vader"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "pupil"
#                 },
#                 {
#                   "text": "Force"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 }
#               ],
#               "text": "his former pupil who turned to the dark side of the Force"
#             },
#             "sentence": " Obi-Wan tells Luke that Vader was his former pupil who turned to the dark side of the Force and killed Anakin."
#           },
#           {
#             "action": {
#               "text": "killed",
#               "verb": {
#                 "text": "kill",
#                 "tense": "past"
#               },
#               "lemmatized": "kill"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "pupil"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Vader",
#                   "type": "Person"
#                 }
#               ],
#               "text": "his former pupil"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Anakin"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Anakin",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.662593,
#                 "type": "negative"
#               },
#               "text": "Anakin"
#             },
#             "sentence": " Obi-Wan tells Luke that Vader was his former pupil who turned to the dark side of the Force and killed Anakin."
#           },
#           {
#             "action": {
#               "text": "presents",
#               "verb": {
#                 "text": "present",
#                 "tense": "present"
#               },
#               "lemmatized": "present"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Obi-Wan Kenobi",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Obi-Wan"
#             },
#             "sentence": " Obi-Wan then presents to Luke his father's weapon \u00e2\u20ac\u201c a lightsaber."
#           }
#         ]
#       },
#       "score": 0.30211335,
#       "id": "10c3239f-ef7c-475b-8d74-946959c99ca5"
#     },
#     {
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "text": "severed",
#               "verb": {
#                 "text": "sever",
#                 "tense": "past"
#               },
#               "lemmatized": "sever"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "hand"
#                 }
#               ],
#               "text": "hand"
#             },
#             "location": {
#               "text": "aboard a medical frigate in the Rebel fleet"
#             },
#             "sentence": "Later, aboard a medical frigate in the Rebel fleet, Luke's severed hand is replaced with a robotic prosthetic."
#           },
#           {
#             "action": {
#               "text": "gaze",
#               "verb": {
#                 "text": "gaze",
#                 "tense": "present"
#               },
#               "lemmatized": "gaze"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "C-3PO"
#                 },
#                 {
#                   "text": "R2-D2"
#                 },
#                 {
#                   "text": "Leia"
#                 },
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.561312,
#                 "type": "negative"
#               },
#               "text": "Luke, Leia, R2-D2, and C-3PO"
#             },
#             "location": {
#               "text": "on the galaxy"
#             },
#             "sentence": " As the Falcon departs, Luke, Leia, R2-D2, and C-3PO gaze out on the galaxy and await word from Lando."
#           },
#           {
#             "action": {
#               "text": "await",
#               "verb": {
#                 "text": "await",
#                 "tense": "present"
#               },
#               "lemmatized": "await"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "word"
#                 }
#               ],
#               "text": "word"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Lando"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Lando",
#                   "type": "Person"
#                 }
#               ],
#               "text": "from Lando"
#             },
#             "sentence": " As the Falcon departs, Luke, Leia, R2-D2, and C-3PO gaze out on the galaxy and await word from Lando."
#           }
#         ]
#       },
#       "score": 0.2759176,
#       "id": "b3726462-7273-4c9e-8ff1-d145daaf76da"
#     },
#     {
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "text": "pursues",
#               "verb": {
#                 "text": "pursue",
#                 "tense": "present"
#               },
#               "lemmatized": "pursue"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "injured Ren"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Ren",
#                   "type": "Person"
#                 }
#               ],
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.773945,
#                 "type": "negative"
#               },
#               "text": "The injured Ren"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Finn"
#                 },
#                 {
#                   "text": "Rey"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Finn",
#                   "type": "Person"
#                 },
#                 {
#                   "text": "Rey",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Finn and Rey"
#             },
#             "sentence": "The injured Ren pursues Finn and Rey to the surface."
#           },
#           {
#             "action": {
#               "text": "takes",
#               "verb": {
#                 "text": "take",
#                 "tense": "present"
#               },
#               "lemmatized": "take"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Rey"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Rey",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Rey"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "lightsaber"
#                 }
#               ],
#               "text": "the lightsaber"
#             },
#             "sentence": " Rey takes the lightsaber and uses the Force to defeat Ren, before they are separated by a fissure as the planet begins to disintegrate and implode."
#           },
#           {
#             "action": {
#               "text": "uses",
#               "verb": {
#                 "text": "use",
#                 "tense": "present"
#               },
#               "lemmatized": "use"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Rey"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Rey",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Rey"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Force"
#                 }
#               ],
#               "text": "the Force",
#               "sentiment": {
#                 "mixed": false,
#                 "score": 0.550991,
#                 "type": "positive"
#               },
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.598507,
#                 "type": "positive"
#               }
#             },
#             "sentence": " Rey takes the lightsaber and uses the Force to defeat Ren, before they are separated by a fissure as the planet begins to disintegrate and implode."
#           },
#           {
#             "action": {
#               "text": "bring",
#               "verb": {
#                 "text": "bring",
#                 "tense": "present"
#               },
#               "lemmatized": "bring"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Snoke orders"
#                 }
#               ],
#               "text": "Snoke orders"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Ren"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Ren",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.462955,
#                 "type": "positive"
#               },
#               "text": "Ren"
#             },
#             "sentence": " Snoke orders Hux to evacuate and bring Ren to him."
#           },
#           {
#             "action": {
#               "text": "mourn",
#               "verb": {
#                 "text": "mourn",
#                 "tense": "present"
#               },
#               "lemmatized": "mourn"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "Rey"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Rey",
#                   "type": "Person"
#                 }
#               ],
#               "text": "Rey"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Han"
#                 },
#                 {
#                   "text": "death"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Han",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": -0.69661,
#                 "type": "negative"
#               },
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.558309,
#                 "type": "negative"
#               },
#               "text": "Han's death"
#             },
#             "sentence": " On D'Qar, the Resistance celebrates while Leia, Chewbacca, and Rey mourn Han's death."
#           },
#           {
#             "action": {
#               "text": "reveals",
#               "verb": {
#                 "text": "reveal",
#                 "tense": "present"
#               },
#               "lemmatized": "reveal"
#             },
#             "subject": {
#               "keywords": [
#                 {
#                   "text": "R2-D2"
#                 }
#               ],
#               "text": "R2-D2"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "oceanic planet"
#                 },
#                 {
#                   "text": "Rey"
#                 },
#                 {
#                   "text": "rest"
#                 },
#                 {
#                   "text": "map"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Rey",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.592674,
#                 "type": "positive"
#               },
#               "sentiment": {
#                 "mixed": false,
#                 "score": -0.366559,
#                 "type": "negative"
#               },
#               "text": "the rest of the map, which Rey follows to the oceanic planet Ahch-To"
#             },
#             "sentence": " R2-D2 awakens and reveals the rest of the map, which Rey follows to the oceanic planet Ahch-To."
#           },
#           {
#             "action": {
#               "text": "finds",
#               "verb": {
#                 "text": "find",
#                 "tense": "present"
#               },
#               "lemmatized": "find"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Han",
#                   "type": "Person"
#                 }
#               ],
#               "text": "She"
#             },
#             "object": {
#               "keywords": [
#                 {
#                   "text": "Luke"
#                 }
#               ],
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.687519,
#                 "type": "positive"
#               },
#               "text": "Luke"
#             },
#             "sentence": " She finds Luke and presents him with the lightsaber."
#           },
#           {
#             "action": {
#               "text": "presents",
#               "verb": {
#                 "text": "present",
#                 "tense": "present"
#               },
#               "lemmatized": "present"
#             },
#             "subject": {
#               "entities": [
#                 {
#                   "text": "Han",
#                   "type": "Person"
#                 }
#               ],
#               "text": "She"
#             },
#             "object": {
#               "sentimentFromSubject": {
#                 "mixed": false,
#                 "score": 0.623833,
#                 "type": "positive"
#               },
#               "entities": [
#                 {
#                   "text": "Luke",
#                   "type": "Person"
#                 }
#               ],
#               "text": "him"
#             },
#             "sentence": " She finds Luke and presents him with the lightsaber."
#           }
#         ]
#       },
#       "score": 0.26108536,
#       "id": "43529a2c-2c98-468f-8523-f200b0d698ad"
#     }
#   ]
# }

# %% [markdown]
# ### Process returned results
#
# If you properly structure the query, Watson is able to do a pretty good job of finding the relevant information. But the result returned is a JSON object. Now your task is to convert that result into an appropriate response that best addresses the original natural language question that was asked.
#
# E.g. if the question was "Who saved Han Solo from Jabba the Hutt?" the answer should ideally just be "The Rebels" and not the entire paragraph describing Han Solo's rescue. But that can be a backup response if you cannot be more specific.
#
# _**Note**: You may have to go back to the previous step and modify the query, especially what you want the Discovery service to return, and this may depend on the intent / dialog node triggered. E.g. study the different parts of a "relation" structure to see how you might construct queries to match them._

# %%
# TODO: Process returned results and compose an appropriate response
response = [rel for result in query_results['results'] 
                for rel in result['enriched_text']['relations'] 
                     if 'is' in rel['action']['lemmatized']
                     if 'entities' in rel['object']        
                     for e in rel['object']['entities']
                     if e['text'] in query_entities]
if response:
    print("Response Found")
    print(response[0]['sentence'])    
else:
    print('Response not found')
# Out:
# Response Found
# On patrol, Han and Chewbacca discover the meteor Luke had planned to investigate is actually a probe droid, which alerts the Empire to the Rebels’ location.

# %% [markdown]
# ## 5. Reflections
#
# **Q**: Now that you have gone through this exercise of designing a system that uses two IBM Watson services, what did you learn? What were some of the strengths and weaknesses of this approach?
#
# **A**:
# What I learnt is obviously how to use IBM watson for some NLP tasks. It is good to know that there is another cloud-based platform that can come in handy for some sentiment analysis, named-entity extraction and even creating a simple chatbot.
# The biggest advantage of this approach is that it is relatively easy to use. It also cover some mandatory nlp subtasks that can be used as the 'blackbox' function. Also, I would like to give credits for the sentiment analysis and relations resulted from the analysis of the sentences of the Discovery Service.
#
# However, I found the conversation service less useful since the we are heaviliy required to hand-coded the questions and actions. I have some experience in building a chatbot with deep neural network. It was relatively easy, what I need to do is to give a lot of close-domain conversational data and the model will learn either to ask approriate question or to answer appropriately.
#
#
#
#
# ## (Optional) Extensions
#
# We have provided a set of sample data files containing Star Wars plot summaries. But as mentioned before, you are free to use your own dataset. In fact, a larger dataset maybe more suitable for use with IBM Watson's NLP services. If you used your own dataset, answer the following questions.
#
# **Q**: What dataset did you use, and in what ways is it different from the sample files provided?
#
# **A**:
#
#
# **Q**: Either include your dataset in the .zip file or repository you submit, or provide clear instructions on how to obtain the dataset, so that your reviewer can run your notebook or inspect the data to verify your results.
#
# **A**:
#
#
# _You can also design a web-based application that utilizes these services and deploy that on Bluemix! If you do, please share with your instructors and peers._
